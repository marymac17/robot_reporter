# %% [markdown]
# # Part 1: Data cleaning

# %%
#import initial libraries

import pandas as pd
import numpy as np

# %%
#import data 

df = pd.read_csv('data/jack.csv')

# %%
# look at basic info about data

df.info()
# this data set consists of 43467 Tweets
# Twarc search for Tweets to @Jack (Twitter CEO Jack Dorsey), in the wake of Twitter's decision to ban Trump from the platform for 24 hours
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43467 entries, 0 to 43466
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            43467 non-null  int64
#  1   tweet_url                     43467 non-null  object
#  2   created_at                    43467 non-null  object
#  3   parsed_created_at             43467 non-null  object
#  4   user_screen_name              43467 non-null  object
#  5   text                          43467 non-null  object
#  6   tweet_type                    43467 non-null  object
#  7   coordinates                   5 non-null      object
#  8   hashtags                      5801 non-null   object
#  9   media                         3173 non-null   object
#  10  urls                          10355 non-null  object
#  11  favorite_count                43467 non-null  int64
#  12  in_reply_to_screen_name       32802 non-null  object
#  13  in_reply_to_status_id         8599 non-null   float64
#  14  in_reply_to_user_id           32802 non-null  float64
#  15  lang                          43467 non-null  object
#  16  place                         856 non-null    object
#  17  possibly_sensitive            13290 non-null  object
#  18  retweet_count                 43467 non-null  int64
#  19  retweet_or_quote_id           20118 non-null  float64
#  20  retweet_or_quote_screen_name  20118 non-null  object
#  21  retweet_or_quote_user_id      20118 non-null  float64
#  22  source                        43421 non-null  object
#  23  user_id                       43467 non-null  int64
#  24  user_created_at               43467 non-null  object
#  25  user_default_profile_image    43467 non-null  bool
#  26  user_description              37161 non-null  object
#  27  user_favourites_count         43467 non-null  int64
#  28  user_followers_count          43467 non-null  int64
#  29  user_friends_count            43467 non-null  int64
#  30  user_listed_count             43467 non-null  int64
#  31  user_location                 29507 non-null  object
#  32  user_name                     43462 non-null  object
#  33  user_statuses_count           43467 non-null  int64
#  34  user_time_zone                0 non-null      float64
#  35  user_urls                     10066 non-null  object
#  36  user_verified                 43467 non-null  bool
# dtypes: bool(2), float64(5), int64(9), object(21)
# memory usage: 11.7+ MB

# %%
# count number of languages in data set

count_lang = df['lang'].unique()
print(len(count_lang), count_lang)
# Out:
# 43 ['en' 'und' 'es' 'bg' 'hi' 'it' 'in' 'ar' 'pt' 'et' 'tr' 'tl' 'pl' 'sv'
#  'fa' 'fr' 'eu' 'de' 'no' 'ht' 'fi' 'lv' 'ja' 'ta' 'ko' 'vi' 'cy' 'nl'
#  'da' 'ro' 'sl' 'ml' 'ru' 'ur' 'hu' 'ca' 'iw' 'bn' 'zh' 'cs' 'sd' 'lt'
#  'ne']

# %%
# tweets are in 43 different languages

# I'll be working only with Tweets in English
# drop tweets in all other languages
# now working with 35556 Tweets 

df = df[df.lang == 'en']
df.shape
# Out:
# (35556, 37)

# %%
# drop unnecessary columns 

df = df.drop(['tweet_url', 'created_at', 'media', 'urls','in_reply_to_screen_name',
       'in_reply_to_status_id', 'in_reply_to_user_id', 'retweet_or_quote_id',
       'retweet_or_quote_screen_name', 'retweet_or_quote_user_id', 'source',
       'user_created_at', 'user_name', 'user_verified', 'user_friends_count', 'user_listed_count',
       'user_statuses_count', 'user_default_profile_image', 'user_description',
       'user_favourites_count', 'user_followers_count', 'coordinates', 'lang', 'user_location', 'user_time_zone', 'user_urls', 'place'], axis=1)

# %%
# check start time & date of data

df.iloc[0]

# first Tweet downloaded Jan 8, 2021 at 7:08:58
# Out:
# id                                                  1347440141388963841
# parsed_created_at                             2021-01-08 07:08:58+00:00
# user_screen_name                                        chinweconstanc4
# text                  @Jack please bring the @verified back, Erica i...
# tweet_type                                                      retweet
# hashtags                        WatchEricaOnYoutube WatchEricaOnYoutube
# favorite_count                                                        4
# possibly_sensitive                                                 True
# retweet_count                                                        16
# user_id                                             1076486309370384386
# Name: 0, dtype: object

# %%
# check end time & date of data 

df.iloc[-1]

# Tweets go back as far as Jan 31, 2020 at 22:07:04
# Out:
# id                                                  1344767054298148870
# parsed_created_at                             2020-12-31 22:07:04+00:00
# user_screen_name                                        SuccessfulErica
# text                  @jack @verified please verify @EricaNlewedim a...
# tweet_type                                                      retweet
# hashtags                                                            NaN
# favorite_count                                                       15
# possibly_sensitive                                                  NaN
# retweet_count                                                        12
# user_id                                             1323407186127630337
# Name: 43466, dtype: object

# %% [markdown]
# # Part 2: Text processing for NLP

# %%
# create variable for "text" column 

text = df['text']

# %%
# tokenize, remove stopwords, remove urls, lowercase, remove punctuation, remove numbers
# import necessary libraries: ntlk etc.

import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 

stop = stopwords.words('english')

punc = list(set(string.punctuation))

def tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_url(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r'', text)

def process_text(text):
    text = remove_url(text)
    text = tokenizer(text)
    text = [word.lower() for word in text]
    text = [re.sub('[0-9]+', '', word) for word in text]
    text = [word for word in text if word not in punc]
    text = [word for word in text if word not in stop]
    text = [each for each in text if len(each) > 1]
    text = [word for word in text if ' ' not in word]
     
    return text

# %%
# apply text processing functions to text

df['processed_text'] = df['text'].apply(process_text)

# %%
# look at some of processed text

pd.set_option('display.max_colwidth', -1)
df['processed_text'][:20]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0     [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 1     [@jack, @verified, please, verify, @ericanlewedim]
# 2     [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 6     [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 7     [@jack, common, cuecat, guy, woz, know, hope, sleep, well, mountain, gold]
# 8     [@jack, god, sees, effort, work, changing, people's, lives, help, i'm, orphan, working, hard, make, difference, family, society, large, absolutely, need, help, meletusejike@gmail.com]
# 9     [@jack, amazing, really, feel, #motherlandmission, talk, ch, pointed, need, supporting, basic, needs, support, places, tech, ecosystem, built, suck, tweeting, well, try, tweet, orgs, week]
# 10    [@jack, time, act, responsible]
# 11    [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 12    [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 13    [@jack, @verified, @twitter, please, re-verify, @ericanlewedim, account, deserves]
# 15    [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 17    [@jack, @twitter, @verified, please, verify, favorite, person, @ericanlewedim, long, overdue, ..., thank, #watchericaonyoutube]
# 18    [@jack, awesome, great, job, fb, walmart, twitter, target, smaller, always, bad]
# 19    [@jack, twitter, apparently, give, shit, post, porn, sexually, explicit, media, platform, god, forbid, share, unpopular, opinion, election, pathetic]
# 21    [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 23    [@jack, right, thing, trump, clear, present, danger, america, cannot, allowed, incite, widespread, #seditionism, via, social, media, #deletetrumpstwitter, #deletehisaccount, #bantrumpfromtwitter]
# 24    [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 25    [@jack, fuck, wrong, twitter, tweet, sucking, dick, sexually, explicit, things, yet, sexually, explicit, option, reporting, tweet, yet, option, misleading, political, election, give, fucking, break]
# 26    [@jack, setting, twittr, tho]
# Name: processed_text, dtype: object

# %%
# part-of-speech tagging 

ready_for_pos = df['processed_text']

def pos_tagging(text):
    pos_tag = [pos_tag(word) for word in ready_for_pos]

df['pos_tagged'] = df.processed_text.apply(lambda x: pos_tag(x))

# %%
# lemmatizing

pos_tagged = df['pos_tagged']

wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
# look at lemmatized text

df['lemmatized'] = lemmatized
lemmatized[:20]
# Out:
# [['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack', '@verified', 'please', 'verify', '@ericanlewedim'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   'common',
#   'cuecat',
#   'guy',
#   'woz',
#   'know',
#   'hope',
#   'sleep',
#   'well',
#   'mountain',
#   'gold'],
#  ['@jack',
#   'god',
#   'see',
#   'effort',
#   'work',
#   'changing',
#   "people's",
#   'life',
#   'help',
#   "i'm",
#   'orphan',
#   'working',
#   'hard',
#   'make',
#   'difference',
#   'family',
#   'society',
#   'large',
#   'absolutely',
#   'need',
#   'help',
#   'meletusejike@gmail.com'],
#  ['@jack',
#   'amazing',
#   'really',
#   'feel',
#   '#motherlandmission',
#   'talk',
#   'ch',
#   'pointed',
#   'need',
#   'supporting',
#   'basic',
#   'need',
#   'support',
#   'place',
#   'tech',
#   'ecosystem',
#   'built',
#   'suck',
#   'tweeting',
#   'well',
#   'try',
#   'tweet',
#   'orgs',
#   'week'],
#  ['@jack', 'time', 'act', 'responsible'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   '@verified',
#   '@twitter',
#   'please',
#   're-verify',
#   '@ericanlewedim',
#   'account',
#   'deserves'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   '@twitter',
#   '@verified',
#   'please',
#   'verify',
#   'favorite',
#   'person',
#   '@ericanlewedim',
#   'long',
#   'overdue',
#   '...',
#   'thank',
#   '#watchericaonyoutube'],
#  ['@jack',
#   'awesome',
#   'great',
#   'job',
#   'fb',
#   'walmart',
#   'twitter',
#   'target',
#   'smaller',
#   'always',
#   'bad'],
#  ['@jack',
#   'twitter',
#   'apparently',
#   'give',
#   'shit',
#   'post',
#   'porn',
#   'sexually',
#   'explicit',
#   'medium',
#   'platform',
#   'god',
#   'forbid',
#   'share',
#   'unpopular',
#   'opinion',
#   'election',
#   'pathetic'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   'right',
#   'thing',
#   'trump',
#   'clear',
#   'present',
#   'danger',
#   'america',
#   'cannot',
#   'allowed',
#   'incite',
#   'widespread',
#   '#seditionism',
#   'via',
#   'social',
#   'medium',
#   '#deletetrumpstwitter',
#   '#deletehisaccount',
#   '#bantrumpfromtwitter'],
#  ['@jack',
#   'please',
#   'bring',
#   '@verified',
#   'back',
#   'erica',
#   'worth',
#   '#watchericaonyoutube',
#   '#watchericaonyoutube'],
#  ['@jack',
#   'fuck',
#   'wrong',
#   'twitter',
#   'tweet',
#   'sucking',
#   'dick',
#   'sexually',
#   'explicit',
#   'thing',
#   'yet',
#   'sexually',
#   'explicit',
#   'option',
#   'reporting',
#   'tweet',
#   'yet',
#   'option',
#   'misleading',
#   'political',
#   'election',
#   'give',
#   'fucking',
#   'break'],
#  ['@jack', 'setting', 'twittr', 'tho']]

# %%
# before vectorizing, cast lists of words back into strings

df['final_docs'] = df['lemmatized'].apply(lambda x: " ".join(x))
pd.set_option('display.max_colwidth', -1)
final_docs = df['final_docs']
final_docs[3000:3020]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 3714    @jack advisor well scavino one
# 3715    @jack twitter need protect democracy encourage peaceful transition power like colleague @facebook done although believe banned life two week danger america #bantrump #banhim #peacefultransferofpower
# 3716    @jack please verify @ericanlewedim
# 3717    @jack pls verify @ericanlewedim @verified great influencer brand ambassador lot brand also award-winning actress please verify #ericatheinfluencer
# 3718    @jack decent human please block
# 3720    @jack please submit trump suspended account review process day
# 3721    @jack please verify @ericanlewedim
# 3722    @jack @twitter bat ... let go
# 3723    @jack #traitortrump still twitter account
# 3724    @jack need follow suit facebook instagram done suspend @realdonaldtrump account indefinitely dangerous tweet need help situation fuel
# 3725    @jack facebook banned trump indefinitely.time twitter stepup.trump incited insurrection he's directly responsible death threat elected official property destruction member trump's family helped incite riot lose twitter account
# 3728    @jack stay go problem analog
# 3729    @jack pls verify @ericanlewedim @verified great influencer brand ambassador lot brand also award-winning actress please verify #ericatheinfluencer
# 3731    @jack step
# 3732    @jack @twittersafety @twittersupport ban trump life please safety menace
# 3734    @jack need shut permanently
# 3735    @jack @twittersupport @twittercomms @twitter embarrassed yet
# 3736    @jack follow lead right thing @twittersupport
# 3737    @jack @twitter please block trump rest term
# 3739    @jack please take note @instagram @facebook ban tr mp's account indefinitely peaceful transition power taken place clearly danger country
# Name: final_docs, dtype: object

# %%
#create document term matrix with TFIDF

#import vectorizing tool (usee TFIDF)
from sklearn.feature_extraction.text import TfidfVectorizer
# set max_features to 2000 (specifies the number of most frequently occurring words for which we want to create feature vectors)
# set min_df to 5 (word must occur in at least 5 documents)
# set max_df to 0.85 (word must not occur in more than 85 percent of the documents) 

tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.85, ngram_range=(1, 2), stop_words='english')  
doc_term_matrix_1 = tfidfconverter.fit_transform(df['final_docs'].values.astype('U'))

# %% [markdown]
# # Part 3: run NMF and LDA models, for topic modeling

# %%
#run NMF model 

#import NMF tool 
from sklearn.decomposition import NMF

nmf_model = NMF(n_components=6)
nmf_Z = nmf_model.fit_transform(doc_term_matrix_1)

# %%
# run LDA model

#import LDA tool 
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 6, max_iter=10, learning_method='online', learning_decay=.9)
lda_Z = lda_model.fit_transform(doc_term_matrix_1)

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model:")
print_topics(lda_model, tfidfconverter )
print("=" * 20)
 
print("NMF Model:")
print_topics(nmf_model, tfidfconverter )
print("=" * 20)
# Out:
# LDA Model:
# Topic 0:
# [('twitter', 289.420898143721), ('ban', 246.12047345411372), ('jack time', 235.18943740253638), ('jack twitter', 233.77553197394104), ('time', 220.33850692006303), ('jack ban', 187.70733686051955), ('mazinnamdikanu', 165.0196655468166), ('verify mazinnamdikanu', 145.68065751019677), ('ban trump', 143.3447475260875), ('twitter shut', 125.97440725484387)]
# Topic 1:
# [('account', 695.58456041917), ('suspend', 675.062884595675), ('trump account', 598.5108708057622), ('trump', 543.186502136906), ('twitter twittersafety', 542.0029336669878), ('time suspend', 540.2541767505044), ('president', 537.5126271785506), ('safety', 528.3778973921864), ('lie', 527.9256121986549), ('incited', 526.2635246761794)]
# Topic 2:
# [('verify', 685.1424292274853), ('jack verify', 487.9622583842279), ('twittersupport', 389.4757858539096), ('ericanlewedim', 379.3257855040641), ('verify ericanlewedim', 322.60914223126895), ('verified', 285.17832052736156), ('jack twittersupport', 262.42798705665166), ('thank', 191.01026062822453), ('account', 164.15294025709454), ('pls', 156.76790859555697)]
# Topic 3:
# [('fipradio', 156.4575562121177), ('jack fipradio', 152.08703083053717), ('hey', 136.498114399806), ('jack hey', 115.44027740479815), ('dude', 100.05967562525348), ('hey jack', 94.43070701075449), ('captjamyl', 85.789532531483), ('suspended', 72.07431097323287), ('suspension', 65.59831740158823), ('working', 64.96470325338336)]
# Topic 4:
# [('twitter', 493.684569521672), ('trump', 411.6981393950712), ('account', 392.54504141120873), ('realdonaldtrump', 382.93740298898524), ('right', 346.51934520108506), ('jack twitter', 274.54753495729875), ('need', 255.9812397991935), ('platform', 234.5665358417106), ('time', 219.12405122044945), ('inciting', 216.0241044388194)]
# Topic 5:
# [('shut', 626.1493836008584), ('jack shut', 579.3846452276873), ('let', 362.74367155793135), ('jack jack', 348.51956196624695), ('year', 342.0402054599073), ('make', 333.46388086571835), ('jack let', 326.45420575510013), ('new', 296.15931666578416), ('let make', 270.5046619642226), ('shut trump', 268.37552898487377)]
# ====================
# NMF Model:
# Topic 0:
# [('twittersafety served', 1.2495504081377284), ('deliberately incited', 1.2495504081377284), ('inception counseled', 1.2495504081377284), ('board inception', 1.2495504081377284), ('trust safety', 1.2495504081377284), ('counseled time', 1.2495504081377284), ('served trust', 1.2495504081377284), ('counseled', 1.2495504081377284), ('account deliberately', 1.2495504081377284), ('mayhem lie', 1.2495504081377284)]
# Topic 1:
# [('twitter', 2.9735595295000805), ('account', 2.0609524466738276), ('jack twitter', 2.019748649530891), ('trump', 1.5784800625280466), ('delete', 1.2466446764585157), ('trump twitter', 1.001385256202397), ('realdonaldtrump', 0.9381907410737388), ('twitter account', 0.8530238009440236), ('jack delete', 0.815658905785746), ('delete account', 0.7978405396315256)]
# Topic 2:
# [('jack time', 1.1870173072723713), ('right history', 0.9116336693299942), ('democracy risk', 0.909667963968759), ('cult leader', 0.9093602343107108), ('leap right', 0.9092783315601333), ('leader putting', 0.9092783315601333), ('service repeatedly', 0.9092783315601333), ('world dangerous', 0.9092783315601333), ('broken world', 0.9092783315601333), ('putting democracy', 0.9092783315601333)]
# Topic 3:
# [('jack let', 2.1594221536431375), ('let', 2.070943822371664), ('let make', 1.9884652869278292), ('make roaring', 1.982844844937284), ('roaring', 1.982844844937284), ('make', 1.883751532368739), ('let trump', 0.15497760545380335), ('trump twitter', 0.07045403864706899), ('jack make', 0.05353734437746475), ('trump', 0.034302608176608754)]
# Topic 4:
# [('verify', 2.877357679023), ('jack verify', 2.3606956383255326), ('ericanlewedim', 1.847135027164272), ('verify ericanlewedim', 1.751010436895118), ('happy', 1.0199795519200219), ('new', 0.9888473342200811), ('new year', 0.9742482990697174), ('year', 0.9726464531591931), ('happy new', 0.9147752181877464), ('jack happy', 0.9042226619839336)]
# Topic 5:
# [('shut', 3.907636064386687), ('jack shut', 3.7221220750693678), ('shut trump', 1.4118833673679398), ('shut account', 0.8262476211013043), ('account', 0.6420972234087942), ('trump', 0.5797111989831596), ('shut realdonaldtrump', 0.4639331240078481), ('trump account', 0.30191183941315475), ('twitter shut', 0.273638459203535), ('realdonaldtrump', 0.22355982471651129)]
# ====================

# %% [markdown]
# # Part 4: Run visualization and testing of LDA model

# %%
# visualization of LDA model 
import pyLDAvis.sklearn

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model, doc_term_matrix_1, tfidfconverter, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=               x          y  topics  cluster       Freq
# topic
# 1      1.465019  -47.625065  1       1        25.255254
# 4      54.854797 -36.476795  2       1        25.111872
# 5      32.212929 -61.444572  3       1        17.319888
# 2      5.111096  -14.110332  4       1        12.969069
# 3      26.350170 -33.374702  5       1        9.813037
# 0      38.109818 -7.222781   6       1        9.530881 , topic_info=               Term        Freq        Total Category  logprob  loglift
# 1888  verify         688.000000  688.000000   Default  30.0000  30.0000
# 928   jack verify    489.000000  489.000000   Default  29.0000  29.0000
# 902   jack shut      516.000000  516.000000   Default  28.0000  28.0000
# 139   ban            479.000000  479.000000   Default  27.0000  27.0000
# 1666  time           932.000000  932.000000   Default  26.0000  26.0000
# ...    ...                  ...         ...       ...      ...      ...
# 1081  man            71.923348   180.388330   Topic6  -4.9035   1.4311
# 1647  thanks         69.603568   196.463906   Topic6  -4.9362   1.3130
# 570   finally        61.794969   79.337890    Topic6  -5.0552   2.1007
# 1817  twittersafety  71.544860   737.299803   Topic6  -4.9087   0.0180
# 11    account        69.946286   1476.027209  Topic6  -4.9313  -0.6987
#
# [315 rows x 6 columns], token_table=      Topic      Freq                  Term
# term
# 11    1      0.453244  account
# 11    2      0.243898  account
# 11    3      0.144306  account
# 11    4      0.111109  account
# 11    6      0.047425  account
# ...  ..           ...      ...
# 1980  6      0.982754  wpmoychallenge kelce
# 1987  2      0.040556  year
# 1987  3      0.883536  year
# 1987  5      0.075318  year
# 1991  3      0.991489  year jack
#
# [440 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 5, 6, 3, 4, 1])

# %%
# test LDA model

# log likelihood (higher score is better)
print("Log likelihood: ", lda_model.score(doc_term_matrix_1))

# perplexity (lower score is better)
print("Perplexity: ", lda_model.perplexity(doc_term_matrix_1))
# Out:
# Log likelihood:  -691028.455410083
# Perplexity:  893.6781241405488

# %%
# cross-validation to find best parameters for LDA model

#import cross-validation tool
from sklearn.model_selection import GridSearchCV

# define search parameters
search_params = {'n_components': [5, 8, 10, 12], 'learning_decay': [.5, .7, .9]}

# initialize model for cross-validation
lda = LatentDirichletAllocation()

# initialize grid search class 
model = GridSearchCV(lda, param_grid=search_params)

# run grid search 
model.fit(doc_term_matrix_1)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 8, 10, 12]})

# %%
# what is best model? 
best_lda_model = model.best_estimator_

# print parameters for best model
print("Parameters for best model: ", model.best_params_)

# print log likelihood score
print("Log likelihood score of best model: ", model.best_score_)

# print perplexity score
print("Perplexity score of best model: ", best_lda_model.perplexity(doc_term_matrix_1))
# Out:
# Parameters for best model:  {'learning_decay': 0.9, 'n_components': 5}
# Log likelihood score of best model:  -156150.2933076067
# Perplexity score of best model:  745.0305368649379

# %%
# 2nd LDA model: running new "best model" parameters

lda_model_2 = LatentDirichletAllocation(n_components = 5, max_iter=10, learning_method='online', learning_decay=0.5)
lda_Z_2 = lda_model_2.fit_transform(doc_term_matrix_1)

# visualization of 2nd LDA model 
pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model_2, doc_term_matrix_1, tfidfconverter, mds='tsne')
panel

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model_2, doc_term_matrix_1, tfidfconverter, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 1      150.222153 -72.269554   1       1        30.510543
# 4      51.163364  -159.968018  2       1        25.751883
# 0     -73.144554   21.523815   3       1        17.560255
# 2     -66.410133  -110.606438  4       1        13.212092
# 3      54.417324   12.443444   5       1        12.965226, topic_info=               Term         Freq        Total Category  logprob  loglift
# 860   jack let       1661.000000  1661.000000  Default  30.0000  30.0000
# 1009  let            1649.000000  1649.000000  Default  29.0000  29.0000
# 1888  verify         1104.000000  1104.000000  Default  28.0000  28.0000
# 928   jack verify    776.000000   776.000000   Default  27.0000  27.0000
# 855   jack jack      625.000000   625.000000   Default  26.0000  26.0000
# ...         ...             ...          ...       ...      ...      ...
# 511   ericanlewedim  432.834353   466.573190   Topic5  -3.4164   1.9678
# 1888  verify         896.715968   1104.394498  Topic5  -2.6881   1.8346
# 1876  verified       339.182369   402.695511   Topic5  -3.6603   1.8713
# 1765  twitter        155.407525   1356.774268  Topic5  -4.4407  -0.1239
# 11    account        148.503449   1117.304761  Topic5  -4.4862   0.0248
#
# [218 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 11    1      0.445715  account
# 11    2      0.388435  account
# 11    3      0.019690  account
# 11    4      0.014320  account
# 11    5      0.133357  account
# ...  ..           ...      ...
# 1969  1      0.996541  work
# 1972  1      0.996334  world
# 1987  3      0.990758  year
# 1987  4      0.007826  year
# 1991  3      0.995992  year jack
#
# [224 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 5, 1, 3, 4])

# %% [markdown]
# # Part 5: Additional data analysis

# %%
# insert NMF model, LDA model 1, and LDA model 2 results back into dataframe
topic_values = nmf_model.transform(doc_term_matrix_1)
df['NMF_topic'] = topic_values.argmax(axis=1)
df.head(1)
# Out:
#                     id          parsed_created_at user_screen_name  \
# 0  1347440141388963841  2021-01-08 07:08:58+00:00  chinweconstanc4
#
#                                                                                                                             text  \
# 0  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
#
#   tweet_type                                 hashtags  favorite_count  \
# 0  retweet    WatchEricaOnYoutube WatchEricaOnYoutube  4
#
#   possibly_sensitive  retweet_count              user_id  \
# 0  True               16             1076486309370384386
#
#                                                                                       processed_text  \
# 0  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
#
#                                                                                                                                                   pos_tagged  \
# 0  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
#
#                                                                                           lemmatized  \
# 0  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
#
#                                                                                 final_docs  \
# 0  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
#
#    NMF_topic
# 0  4

# %%
topic_values = lda_model.transform(doc_term_matrix_1)
df['LDA1_topic'] = topic_values.argmax(axis=1)
df.head(1)
# Out:
#                     id          parsed_created_at user_screen_name  \
# 0  1347440141388963841  2021-01-08 07:08:58+00:00  chinweconstanc4
#
#                                                                                                                             text  \
# 0  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
#
#   tweet_type                                 hashtags  favorite_count  \
# 0  retweet    WatchEricaOnYoutube WatchEricaOnYoutube  4
#
#   possibly_sensitive  retweet_count              user_id  \
# 0  True               16             1076486309370384386
#
#                                                                                       processed_text  \
# 0  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
#
#                                                                                                                                                   pos_tagged  \
# 0  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
#
#                                                                                           lemmatized  \
# 0  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
#
#                                                                                 final_docs  \
# 0  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
#
#    NMF_topic  LDA1_topic
# 0  4          0

# %%
topic_values = lda_model_2.transform(doc_term_matrix_1)
df['LDA2_topic'] = topic_values.argmax(axis=1)
df.head(20)
# Out:
#                      id          parsed_created_at user_screen_name  \
# 0   1347440141388963841  2021-01-08 07:08:58+00:00  chinweconstanc4
# 1   1347439976796090369  2021-01-08 07:08:19+00:00  adaobi_ani
# 2   1347439857308729345  2021-01-08 07:07:50+00:00  elitecompany41
# 6   1347439335407235073  2021-01-08 07:05:46+00:00  Candice__Green
# 7   1347439190196314114  2021-01-08 07:05:11+00:00  SrslySteve
# 8   1347438729552560128  2021-01-08 07:03:21+00:00  91011_gray
# 9   1347438417081102336  2021-01-08 07:02:07+00:00  91011_gray
# 10  1347438167465615360  2021-01-08 07:01:07+00:00  Justice67662170
# 11  1347437779429453824  2021-01-08 06:59:35+00:00  Nkiruka70920363
# 12  1347437582800592898  2021-01-08 06:58:48+00:00  mpho_jacqueline
# 13  1347437530896097280  2021-01-08 06:58:36+00:00  Charmingchyka
# 15  1347437341720391681  2021-01-08 06:57:51+00:00  Tirzahhhhh
# 17  1347437260602486784  2021-01-08 06:57:31+00:00  Tirzahhhhh
# 18  1347437258471829505  2021-01-08 06:57:31+00:00  SMcTavishESQ
# 19  1347436918880006144  2021-01-08 06:56:10+00:00  eurostep_stark
# 21  1347436787283550208  2021-01-08 06:55:38+00:00  AsheAssay
# 23  1347436726457831428  2021-01-08 06:55:24+00:00  mattosso83
# 24  1347436647059750912  2021-01-08 06:55:05+00:00  Unpretendable
# 25  1347436618190381056  2021-01-08 06:54:58+00:00  eurostep_stark
# 26  1347436146834501633  2021-01-08 06:53:06+00:00  MorrbidButEpic
#
#                                                                                                                                                                                                                                                                                                          text  \
# 0   @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 1   @Jack and @verified please verify @EricaNlewedim
# 2   @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 6   @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 7   @jack You have more in common with the Cuecat guy than you do with Woz, and you know that. Hope you sleep well on your mountain of gold.
# 8   @jack God sees your effort and work in changing people's lives with your help. I'm an orphan that is working hard to make a difference in my family and society at large but I absolutely need help. meletusejike12@gmail.com.
# 9   @jack Amazing and really feel that the #MotherlandMission talk in CH pointed to a need for supporting basic needs support in places where tech ecosystem is built. I suck at tweeting well 😇 but I’ll try to tweet the orgs doing this during week
# 10  @jack time for you to act and be responsible. https://t.co/2miuioPkeL
# 11  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 12  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 13  @jack @verified @Twitter please re-verify @EricaNlewedim account. She deserves it 🙏🙏🙏 https://t.co/YK09n6bNh3
# 15  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 17  @jack @Twitter @Verified please can you Verify my favorite person @EricaNlewedim ? It is long overdue...Thank you 🙏 #WatchEricaOnYoutube
# 18  @jack you're awesome. You're doing a great job. FB is Walmart but Twitter is Target. Being smaller is not always bad.
# 19  @jack and Twitter apparently don’t give a shit if you post porn, or other sexually explicit media on their platform, but God forbid you share an unpopular opinion about an election. Pathetic. https://t.co/wBkR3qOOYf
# 21  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 23  @jack You're up. Do the right thing. trump is a clear and present danger to America. He cannot be allowed the incite widespread #Seditionism via social media. #DeleteTrumpsTwitter #deletehisaccount #BanTrumpFromTwitter https://t.co/Amd84pxOxB
# 24  @Jack please bring the @verified back, Erica is worth it.\n#WatchEricaOnYoutube\n#WatchEricaOnYoutube https://t.co/jSv54rTzcx
# 25  @jack what the fuck is wrong with Twitter? You can tweet about sucking dick and other sexually explicit things, yet there’s no “sexually explicit” option when reporting a tweet, yet there’s an option for “misleading about a political election!?” GIVE ME A FUCKING BREAK 🤣🤣🤣 https://t.co/K33EFDfF7t
# 26  @jack He do be setting up his twittr tho 😳
#
#    tweet_type  \
# 0   retweet
# 1   retweet
# 2   retweet
# 6   retweet
# 7   reply
# 8   retweet
# 9   retweet
# 10  quote
# 11  retweet
# 12  retweet
# 13  retweet
# 15  retweet
# 17  retweet
# 18  original
# 19  original
# 21  retweet
# 23  quote
# 24  retweet
# 25  original
# 26  retweet
#
#                                                                 hashtags  \
# 0   WatchEricaOnYoutube WatchEricaOnYoutube
# 1   NaN
# 2   WatchEricaOnYoutube WatchEricaOnYoutube
# 6   WatchEricaOnYoutube WatchEricaOnYoutube
# 7   NaN
# 8   NaN
# 9   MotherlandMission
# 10  NaN
# 11  WatchEricaOnYoutube WatchEricaOnYoutube
# 12  WatchEricaOnYoutube WatchEricaOnYoutube
# 13  NaN
# 15  WatchEricaOnYoutube WatchEricaOnYoutube
# 17  WatchEricaOnYoutube
# 18  NaN
# 19  NaN
# 21  WatchEricaOnYoutube WatchEricaOnYoutube
# 23  Seditionism DeleteTrumpsTwitter deletehisaccount BanTrumpFromTwitter
# 24  WatchEricaOnYoutube WatchEricaOnYoutube
# 25  NaN
# 26  NaN
#
#     favorite_count possibly_sensitive  retweet_count              user_id  \
# 0   4               True               16             1076486309370384386
# 1   15              NaN                11             1318431923660795907
# 2   4               False              16             1322512992769028096
# 6   4               False              16             979406523267985411
# 7   0               NaN                0              4707712217
# 8   1               NaN                1              2169363216
# 9   1               NaN                1              2169363216
# 10  0               False              0              964590993336164355
# 11  4               False              16             1315258533630410753
# 12  4               False              16             1292454108549570560
# 13  90              False              40             1258353773791019008
# 15  4               False              16             1327150531639463937
# 17  3               NaN                6              1327150531639463937
# 18  0               NaN                0              1001983600676560896
# 19  0               False              0              2495555652
# 21  4               False              16             1311685767866048512
# 23  0               False              0              418510092
# 24  4               False              16             1320333337077178373
# 25  0               False              0              2495555652
# 26  2               NaN                1              1325659750617538560
#
#                                                                                                                                                                                             processed_text  \
# 0   [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 1   [@jack, @verified, please, verify, @ericanlewedim]
# 2   [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 6   [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 7   [@jack, common, cuecat, guy, woz, know, hope, sleep, well, mountain, gold]
# 8   [@jack, god, sees, effort, work, changing, people's, lives, help, i'm, orphan, working, hard, make, difference, family, society, large, absolutely, need, help, meletusejike@gmail.com]
# 9   [@jack, amazing, really, feel, #motherlandmission, talk, ch, pointed, need, supporting, basic, needs, support, places, tech, ecosystem, built, suck, tweeting, well, try, tweet, orgs, week]
# 10  [@jack, time, act, responsible]
# 11  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 12  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 13  [@jack, @verified, @twitter, please, re-verify, @ericanlewedim, account, deserves]
# 15  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 17  [@jack, @twitter, @verified, please, verify, favorite, person, @ericanlewedim, long, overdue, ..., thank, #watchericaonyoutube]
# 18  [@jack, awesome, great, job, fb, walmart, twitter, target, smaller, always, bad]
# 19  [@jack, twitter, apparently, give, shit, post, porn, sexually, explicit, media, platform, god, forbid, share, unpopular, opinion, election, pathetic]
# 21  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 23  [@jack, right, thing, trump, clear, present, danger, america, cannot, allowed, incite, widespread, #seditionism, via, social, media, #deletetrumpstwitter, #deletehisaccount, #bantrumpfromtwitter]
# 24  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 25  [@jack, fuck, wrong, twitter, tweet, sucking, dick, sexually, explicit, things, yet, sexually, explicit, option, reporting, tweet, yet, option, misleading, political, election, give, fucking, break]
# 26  [@jack, setting, twittr, tho]
#
#                                                                                                                                                                                                                                                                                                                                                      pos_tagged  \
# 0   [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 1   [(@jack, RB), (@verified, JJ), (please, NN), (verify, VB), (@ericanlewedim, NN)]
# 2   [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 6   [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 7   [(@jack, NN), (common, JJ), (cuecat, NN), (guy, NN), (woz, NN), (know, VBP), (hope, NN), (sleep, RB), (well, RB), (mountain, VB), (gold, NN)]
# 8   [(@jack, NN), (god, NN), (sees, VBZ), (effort, NN), (work, NN), (changing, VBG), (people's, NN), (lives, NNS), (help, VBP), (i'm, VB), (orphan, JJ), (working, VBG), (hard, JJ), (make, NN), (difference, NN), (family, NN), (society, NN), (large, JJ), (absolutely, RB), (need, VBP), (help, NN), (meletusejike@gmail.com, VB)]
# 9   [(@jack, NN), (amazing, VBG), (really, RB), (feel, VB), (#motherlandmission, NN), (talk, NN), (ch, NN), (pointed, VBD), (need, MD), (supporting, VBG), (basic, JJ), (needs, NNS), (support, NN), (places, NNS), (tech, VBP), (ecosystem, NN), (built, VBN), (suck, JJ), (tweeting, NN), (well, RB), (try, VB), (tweet, NN), (orgs, IN), (week, NN)]
# 10  [(@jack, NN), (time, NN), (act, NN), (responsible, JJ)]
# 11  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 12  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 13  [(@jack, RB), (@verified, JJ), (@twitter, JJ), (please, NN), (re-verify, JJ), (@ericanlewedim, NNP), (account, NN), (deserves, NNS)]
# 15  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 17  [(@jack, NN), (@twitter, NN), (@verified, VBD), (please, JJ), (verify, VB), (favorite, JJ), (person, NN), (@ericanlewedim, NNP), (long, RB), (overdue, JJ), (..., :), (thank, NN), (#watchericaonyoutube, NN)]
# 18  [(@jack, RB), (awesome, JJ), (great, JJ), (job, NN), (fb, JJ), (walmart, NN), (twitter, NN), (target, NN), (smaller, JJR), (always, RB), (bad, JJ)]
# 19  [(@jack, NN), (twitter, NN), (apparently, RB), (give, VBP), (shit, JJ), (post, NN), (porn, VBN), (sexually, RB), (explicit, JJ), (media, NNS), (platform, NN), (god, NN), (forbid, NN), (share, NN), (unpopular, JJ), (opinion, NN), (election, NN), (pathetic, JJ)]
# 21  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 23  [(@jack, RB), (right, JJ), (thing, NN), (trump, NN), (clear, JJ), (present, JJ), (danger, NN), (america, NN), (cannot, NN), (allowed, VBN), (incite, JJ), (widespread, JJ), (#seditionism, NN), (via, IN), (social, JJ), (media, NNS), (#deletetrumpstwitter, JJ), (#deletehisaccount, NNP), (#bantrumpfromtwitter, NN)]
# 24  [(@jack, NN), (please, NN), (bring, VB), (@verified, VBN), (back, RB), (erica, JJ), (worth, NN), (#watchericaonyoutube, NNP), (#watchericaonyoutube, NN)]
# 25  [(@jack, RB), (fuck, NN), (wrong, JJ), (twitter, NN), (tweet, NN), (sucking, VBG), (dick, JJ), (sexually, RB), (explicit, JJ), (things, NNS), (yet, RB), (sexually, RB), (explicit, JJ), (option, NN), (reporting, VBG), (tweet, NN), (yet, RB), (option, NN), (misleading, VBG), (political, JJ), (election, NN), (give, VBP), (fucking, NN), (break, NN)]
# 26  [(@jack, NN), (setting, VBG), (twittr, NNS), (tho, NNS)]
#
#                                                                                                                                                                                                lemmatized  \
# 0   [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 1   [@jack, @verified, please, verify, @ericanlewedim]
# 2   [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 6   [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 7   [@jack, common, cuecat, guy, woz, know, hope, sleep, well, mountain, gold]
# 8   [@jack, god, see, effort, work, changing, people's, life, help, i'm, orphan, working, hard, make, difference, family, society, large, absolutely, need, help, meletusejike@gmail.com]
# 9   [@jack, amazing, really, feel, #motherlandmission, talk, ch, pointed, need, supporting, basic, need, support, place, tech, ecosystem, built, suck, tweeting, well, try, tweet, orgs, week]
# 10  [@jack, time, act, responsible]
# 11  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 12  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 13  [@jack, @verified, @twitter, please, re-verify, @ericanlewedim, account, deserves]
# 15  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 17  [@jack, @twitter, @verified, please, verify, favorite, person, @ericanlewedim, long, overdue, ..., thank, #watchericaonyoutube]
# 18  [@jack, awesome, great, job, fb, walmart, twitter, target, smaller, always, bad]
# 19  [@jack, twitter, apparently, give, shit, post, porn, sexually, explicit, medium, platform, god, forbid, share, unpopular, opinion, election, pathetic]
# 21  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 23  [@jack, right, thing, trump, clear, present, danger, america, cannot, allowed, incite, widespread, #seditionism, via, social, medium, #deletetrumpstwitter, #deletehisaccount, #bantrumpfromtwitter]
# 24  [@jack, please, bring, @verified, back, erica, worth, #watchericaonyoutube, #watchericaonyoutube]
# 25  [@jack, fuck, wrong, twitter, tweet, sucking, dick, sexually, explicit, thing, yet, sexually, explicit, option, reporting, tweet, yet, option, misleading, political, election, give, fucking, break]
# 26  [@jack, setting, twittr, tho]
#
#                                                                                                                                                                           final_docs  \
# 0   @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 1   @jack @verified please verify @ericanlewedim
# 2   @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 6   @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 7   @jack common cuecat guy woz know hope sleep well mountain gold
# 8   @jack god see effort work changing people's life help i'm orphan working hard make difference family society large absolutely need help meletusejike@gmail.com
# 9   @jack amazing really feel #motherlandmission talk ch pointed need supporting basic need support place tech ecosystem built suck tweeting well try tweet orgs week
# 10  @jack time act responsible
# 11  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 12  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 13  @jack @verified @twitter please re-verify @ericanlewedim account deserves
# 15  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 17  @jack @twitter @verified please verify favorite person @ericanlewedim long overdue ... thank #watchericaonyoutube
# 18  @jack awesome great job fb walmart twitter target smaller always bad
# 19  @jack twitter apparently give shit post porn sexually explicit medium platform god forbid share unpopular opinion election pathetic
# 21  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 23  @jack right thing trump clear present danger america cannot allowed incite widespread #seditionism via social medium #deletetrumpstwitter #deletehisaccount #bantrumpfromtwitter
# 24  @jack please bring @verified back erica worth #watchericaonyoutube #watchericaonyoutube
# 25  @jack fuck wrong twitter tweet sucking dick sexually explicit thing yet sexually explicit option reporting tweet yet option misleading political election give fucking break
# 26  @jack setting twittr tho
#
#     NMF_topic  LDA1_topic  LDA2_topic
# 0   4          0           2
# 1   4          2           3
# 2   4          0           2
# 6   4          0           2
# 7   1          5           0
# 8   3          3           0
# 9   1          4           0
# 10  2          0           1
# 11  4          0           2
# 12  4          0           2
# 13  4          2           3
# 15  4          0           2
# 17  4          2           2
# 18  1          0           1
# 19  1          5           0
# 21  4          0           2
# 23  1          4           2
# 24  4          0           2
# 25  1          1           0
# 26  0          0           0

# %%
df.columns
# Out:
# Index(['id', 'parsed_created_at', 'user_screen_name', 'text', 'tweet_type',
#        'hashtags', 'favorite_count', 'possibly_sensitive', 'retweet_count',
#        'user_id', 'processed_text', 'pos_tagged', 'lemmatized', 'final_docs',
#        'NMF_topic', 'LDA1_topic', 'LDA2_topic'],
#       dtype='object')

# %%
# drop unnecessary columns
df = df.drop(['id', 'parsed_created_at', 'user_screen_name', 'text',
       'hashtags', 'user_id', 'processed_text', 'pos_tagged', 'lemmatized', 'final_docs'], axis=1)

# %%
df.head(20)
# Out:
#    tweet_type  favorite_count possibly_sensitive  retweet_count  NMF_topic  \
# 0   retweet    4               True               16             4
# 1   retweet    15              NaN                11             4
# 2   retweet    4               False              16             4
# 6   retweet    4               False              16             4
# 7   reply      0               NaN                0              1
# 8   retweet    1               NaN                1              3
# 9   retweet    1               NaN                1              1
# 10  quote      0               False              0              2
# 11  retweet    4               False              16             4
# 12  retweet    4               False              16             4
# 13  retweet    90              False              40             4
# 15  retweet    4               False              16             4
# 17  retweet    3               NaN                6              4
# 18  original   0               NaN                0              1
# 19  original   0               False              0              1
# 21  retweet    4               False              16             4
# 23  quote      0               False              0              1
# 24  retweet    4               False              16             4
# 25  original   0               False              0              1
# 26  retweet    2               NaN                1              0
#
#     LDA1_topic  LDA2_topic
# 0   0           2
# 1   2           3
# 2   0           2
# 6   0           2
# 7   5           0
# 8   3           0
# 9   4           0
# 10  0           1
# 11  0           2
# 12  0           2
# 13  2           3
# 15  0           2
# 17  2           2
# 18  0           1
# 19  5           0
# 21  0           2
# 23  4           2
# 24  0           2
# 25  1           0
# 26  0           0

# %%
df.columns
# Out:
# Index(['tweet_type', 'favorite_count', 'possibly_sensitive', 'retweet_count',
#        'NMF_topic', 'LDA1_topic', 'LDA2_topic'],
#       dtype='object')
