# %%
import pandas as pd
import numpy as np

# %%
#import data (duplicate Tweets already removed using Twarc)

df = pd.read_csv("data/huckabee.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22370 entries, 0 to 22369
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            22370 non-null  int64
#  1   tweet_url                     22370 non-null  object
#  2   created_at                    22370 non-null  object
#  3   parsed_created_at             22370 non-null  object
#  4   user_screen_name              22370 non-null  object
#  5   text                          22370 non-null  object
#  6   tweet_type                    22370 non-null  object
#  7   coordinates                   0 non-null      float64
#  8   hashtags                      851 non-null    object
#  9   media                         1193 non-null   object
#  10  urls                          2897 non-null   object
#  11  favorite_count                22370 non-null  int64
#  12  in_reply_to_screen_name       2661 non-null   object
#  13  in_reply_to_status_id         2559 non-null   float64
#  14  in_reply_to_user_id           2661 non-null   float64
#  15  lang                          22370 non-null  object
#  16  place                         103 non-null    object
#  17  possibly_sensitive            4002 non-null   object
#  18  retweet_count                 22370 non-null  int64
#  19  retweet_or_quote_id           17670 non-null  float64
#  20  retweet_or_quote_screen_name  17670 non-null  object
#  21  retweet_or_quote_user_id      17670 non-null  float64
#  22  source                        22368 non-null  object
#  23  user_id                       22370 non-null  int64
#  24  user_created_at               22370 non-null  object
#  25  user_default_profile_image    22370 non-null  bool
#  26  user_description              18046 non-null  object
#  27  user_favourites_count         22370 non-null  int64
#  28  user_followers_count          22370 non-null  int64
#  29  user_friends_count            22370 non-null  int64
#  30  user_listed_count             22370 non-null  int64
#  31  user_location                 14095 non-null  object
#  32  user_name                     22369 non-null  object
#  33  user_statuses_count           22370 non-null  int64
#  34  user_time_zone                0 non-null      float64
#  35  user_urls                     3532 non-null   object
#  36  user_verified                 22370 non-null  bool
# dtypes: bool(2), float64(6), int64(9), object(20)
# memory usage: 6.0+ MB

# %%
# I'll be working only with Tweets in English
# drop tweets in all other languages
# now working with 38884 Tweets 

df = df[df.lang == 'en']
df.shape

# after non-English removed, just 21860 Tweets left
# Out:
# (21860, 37)

# %%
# drop unnecessary columns 

df = df.drop(['tweet_url', 'created_at', 'media', 'urls','in_reply_to_screen_name',
       'in_reply_to_status_id', 'in_reply_to_user_id', 'retweet_or_quote_id',
       'retweet_or_quote_screen_name', 'retweet_or_quote_user_id', 'source',
       'user_created_at', 'user_name', 'user_verified', 'user_friends_count', 'user_listed_count',
       'user_statuses_count', 'user_default_profile_image', 'user_description',
       'user_favourites_count', 'user_followers_count', 'coordinates', 'lang', 'user_location', 'user_time_zone', 'user_urls', 'place'], axis=1)

# %%
# drop retweets

df = df[df.tweet_type != 'retweet']

# %%
df.info()
#after retweets removed, just 4752 Tweets left
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4752 entries, 8 to 22362
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4752 non-null   int64
#  1   parsed_created_at   4752 non-null   object
#  2   user_screen_name    4752 non-null   object
#  3   text                4752 non-null   object
#  4   tweet_type          4752 non-null   object
#  5   hashtags            277 non-null    object
#  6   favorite_count      4752 non-null   int64
#  7   possibly_sensitive  1746 non-null   object
#  8   retweet_count       4752 non-null   int64
#  9   user_id             4752 non-null   int64
# dtypes: int64(4), object(6)
# memory usage: 408.4+ KB

# %%
# check end time & date of data

df.iloc[0]

# last Tweet downloaded 2021-01-25 03:06:31+00:00
# Out:
# id                                                  1353539721473961986
# parsed_created_at                             2021-01-25 03:06:31+00:00
# user_screen_name                                              ElectLucy
# text                  🚨#BREAKING : Sarah Huckabee #Sanders  expected...
# tweet_type                                                        quote
# hashtags                                      BREAKING Sanders Arkansas
# favorite_count                                                        0
# possibly_sensitive                                                False
# retweet_count                                                         0
# user_id                                             1207718617707687943
# Name: 8, dtype: object

# %%
# check start time & date of data 

df.iloc[-1]

# first Tweet on  2021-01-17 01:11:36+00:00
# Out:
# id                                                  1350611696675647490
# parsed_created_at                             2021-01-17 01:11:36+00:00
# user_screen_name                                                 vahb17
# text                  Dershowitz on CBN w Huckabee just compared Tru...
# tweet_type                                                     original
# hashtags                                                            NaN
# favorite_count                                                        1
# possibly_sensitive                                                  NaN
# retweet_count                                                         0
# user_id                                             1155783466983862272
# Name: 22362, dtype: object

# %%
# create variable for "text" column 

text = df['text']

# %%
# tokenize, remove stopwords, remove urls, lowercase, remove punctuation, remove numbers

# import necessary libraries: ntlk etc.

import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 


stop = stopwords.words('english')

punc = list(set(string.punctuation))

def tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_url(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r'', text)

def process_text(text):
    text = remove_url(text)
    text = tokenizer(text)
    text = [word.lower() for word in text]
    text = [re.sub('[0-9]+', '', word) for word in text]
    text = [word for word in text if word not in punc]
    text = [word for word in text if word not in stop]
    text = [each for each in text if len(each) > 1]
    text = [word for word in text if ' ' not in word]
     
    return text

# %%
# apply text processing functions to text

df['processed_text'] = df['text'].apply(process_text)

# %%
# look at some of processed text

pd.set_option('display.max_colwidth', -1)
df['processed_text'][:20]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 8      [#breaking, sarah, huckabee, #sanders, expected, announce, run, governor, #arkansas]
# 11     [yes, sarah, huckabee, sanders, good, chance, becoming, next, arkansas, governor, take, look, many, states, run, republican, governors]
# 16     [@palmerreport, sarah, huckabee, sanders, running, governor, arkansas]
# 22     [headline, four, years, governor, arkansas, former, white, house, press, secretary, sarah, huckabee, sanders, becomes, first, elected, official, endorse, donald, trump, second, re-election, bid]
# 26     [nbc, news, sarah, huckabee, sanders, ex-trump, press, secretary, run, arkansas, governor, via, @googlenews]
# 27     [@acnewsitics, arkansas, beautiful, state, many, good, people, sarah, huckabee, sanders, one]
# 65     [meck, report, sarah, huckabee, sanders, run, governor, thehill, go, sarah, gov, great, gov, like, dad, @repbarrymoore, @sarahhuckabee, @govmikehuckabee, @jackngraham, #trump, @mailonline, @ingrahamangle, @tuckercarlson, @nypost]
# 66     [sarah, huckabee, sanders, trump, dress, pearls, vile, liar, hire, least, sean, spicer, funny, spitn, spurtn, alternative, facts, sarah, spewn, crap, show, disgrace, women, mothers, church, country, stay, home, sarah, bake, fake, piea, pie]
# 95     [@cvalentine, @cnn, well, elected, dad, mike, huckabee, sooooo, optimistic]
# 97     [picture, huckabee, sanders, smiling]
# 98     [@ap, folks, elected, mike, huckabee, loved, sarah, definitely, going, win, heard, first]
# 108    [@drgjackbrown, telling, somebody, kind, people, live, south, sorry, call, redneck, states, grew, one, see, name, sarah, huckabee, sanders]
# 118    [@urocklive, huckabee, tuberville]
# 157    [oh, fuck, huckabee, arkansas, like]
# 160    [@acnewsitics, sarah, huckabee's, dad, probably, dumb, dumber, .., interviewing, rudy, giuliani, fox, program, right, ..., mother's, house, .., get, leave, ..., unfortunately, mother, drank, kool-aid]
# 167    [@jdawsey, sarah, huckabee, sanders, candidate, much, arkansas, deserves, thinking, part, souls, sizeable, fat-smeared, chunk, arkansas]
# 190    [@lukepruitt, know, arkansas, democrat, campaign, use, donation, happy, pitch, sure, sarah, huckabee, sanders, democratic, opposition, yet, governor]
# 203    [sarah, huckabee, wants, run, governor, ar, absolutely, integrity, honor, morales, anything, positive, mention, character, possibly, bring, elected, appointed, position, destruction, corruption]
# 209    [arkansas, stupidest, state, united, states, nobody, state, education, inbred, sleeping, siblings, sarah, huckabee, sanders, ugly, parents, least, cousins, sarah, sanders, next, governor]
# 210    [thing, sarah, huckabee, sanders, running, governor, arkansas, via, @palmerreport]
# Name: processed_text, dtype: object

# %%
# part-of-speech tagging 

ready_for_pos = df['processed_text']

def pos_tagging(text):
    pos_tag = [pos_tag(word) for word in ready_for_pos]

df['pos_tagged'] = df.processed_text.apply(lambda x: pos_tag(x))

# %%
# lemmatizing

pos_tagged = df['pos_tagged']

wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
# look at lemmatized text

df['lemmatized'] = lemmatized
lemmatized[:20]
# Out:
# [['#breaking',
#   'sarah',
#   'huckabee',
#   '#sanders',
#   'expected',
#   'announce',
#   'run',
#   'governor',
#   '#arkansas'],
#  ['yes',
#   'sarah',
#   'huckabee',
#   'sander',
#   'good',
#   'chance',
#   'becoming',
#   'next',
#   'arkansas',
#   'governor',
#   'take',
#   'look',
#   'many',
#   'state',
#   'run',
#   'republican',
#   'governor'],
#  ['@palmerreport',
#   'sarah',
#   'huckabee',
#   'sander',
#   'running',
#   'governor',
#   'arkansas'],
#  ['headline',
#   'four',
#   'year',
#   'governor',
#   'arkansas',
#   'former',
#   'white',
#   'house',
#   'press',
#   'secretary',
#   'sarah',
#   'huckabee',
#   'sander',
#   'becomes',
#   'first',
#   'elected',
#   'official',
#   'endorse',
#   'donald',
#   'trump',
#   'second',
#   're-election',
#   'bid'],
#  ['nbc',
#   'news',
#   'sarah',
#   'huckabee',
#   'sander',
#   'ex-trump',
#   'press',
#   'secretary',
#   'run',
#   'arkansas',
#   'governor',
#   'via',
#   '@googlenews'],
#  ['@acnewsitics',
#   'arkansas',
#   'beautiful',
#   'state',
#   'many',
#   'good',
#   'people',
#   'sarah',
#   'huckabee',
#   'sander',
#   'one'],
#  ['meck',
#   'report',
#   'sarah',
#   'huckabee',
#   'sander',
#   'run',
#   'governor',
#   'thehill',
#   'go',
#   'sarah',
#   'gov',
#   'great',
#   'gov',
#   'like',
#   'dad',
#   '@repbarrymoore',
#   '@sarahhuckabee',
#   '@govmikehuckabee',
#   '@jackngraham',
#   '#trump',
#   '@mailonline',
#   '@ingrahamangle',
#   '@tuckercarlson',
#   '@nypost'],
#  ['sarah',
#   'huckabee',
#   'sander',
#   'trump',
#   'dress',
#   'pearl',
#   'vile',
#   'liar',
#   'hire',
#   'least',
#   'sean',
#   'spicer',
#   'funny',
#   'spitn',
#   'spurtn',
#   'alternative',
#   'fact',
#   'sarah',
#   'spewn',
#   'crap',
#   'show',
#   'disgrace',
#   'woman',
#   'mother',
#   'church',
#   'country',
#   'stay',
#   'home',
#   'sarah',
#   'bake',
#   'fake',
#   'piea',
#   'pie'],
#  ['@cvalentine',
#   '@cnn',
#   'well',
#   'elected',
#   'dad',
#   'mike',
#   'huckabee',
#   'sooooo',
#   'optimistic'],
#  ['picture', 'huckabee', 'sander', 'smiling'],
#  ['@ap',
#   'folk',
#   'elected',
#   'mike',
#   'huckabee',
#   'loved',
#   'sarah',
#   'definitely',
#   'going',
#   'win',
#   'heard',
#   'first'],
#  ['@drgjackbrown',
#   'telling',
#   'somebody',
#   'kind',
#   'people',
#   'live',
#   'south',
#   'sorry',
#   'call',
#   'redneck',
#   'state',
#   'grew',
#   'one',
#   'see',
#   'name',
#   'sarah',
#   'huckabee',
#   'sander'],
#  ['@urocklive', 'huckabee', 'tuberville'],
#  ['oh', 'fuck', 'huckabee', 'arkansas', 'like'],
#  ['@acnewsitics',
#   'sarah',
#   "huckabee's",
#   'dad',
#   'probably',
#   'dumb',
#   'dumber',
#   '..',
#   'interviewing',
#   'rudy',
#   'giuliani',
#   'fox',
#   'program',
#   'right',
#   '...',
#   "mother's",
#   'house',
#   '..',
#   'get',
#   'leave',
#   '...',
#   'unfortunately',
#   'mother',
#   'drank',
#   'kool-aid'],
#  ['@jdawsey',
#   'sarah',
#   'huckabee',
#   'sander',
#   'candidate',
#   'much',
#   'arkansas',
#   'deserves',
#   'thinking',
#   'part',
#   'soul',
#   'sizeable',
#   'fat-smeared',
#   'chunk',
#   'arkansas'],
#  ['@lukepruitt',
#   'know',
#   'arkansas',
#   'democrat',
#   'campaign',
#   'use',
#   'donation',
#   'happy',
#   'pitch',
#   'sure',
#   'sarah',
#   'huckabee',
#   'sander',
#   'democratic',
#   'opposition',
#   'yet',
#   'governor'],
#  ['sarah',
#   'huckabee',
#   'want',
#   'run',
#   'governor',
#   'ar',
#   'absolutely',
#   'integrity',
#   'honor',
#   'morale',
#   'anything',
#   'positive',
#   'mention',
#   'character',
#   'possibly',
#   'bring',
#   'elected',
#   'appointed',
#   'position',
#   'destruction',
#   'corruption'],
#  ['arkansas',
#   'stupidest',
#   'state',
#   'united',
#   'state',
#   'nobody',
#   'state',
#   'education',
#   'inbred',
#   'sleeping',
#   'sibling',
#   'sarah',
#   'huckabee',
#   'sander',
#   'ugly',
#   'parent',
#   'least',
#   'cousin',
#   'sarah',
#   'sander',
#   'next',
#   'governor'],
#  ['thing',
#   'sarah',
#   'huckabee',
#   'sander',
#   'running',
#   'governor',
#   'arkansas',
#   'via',
#   '@palmerreport']]

# %%
# before vectorizing, cast lists of words back into strings

df['final_docs'] = df['lemmatized'].apply(lambda x: " ".join(x))
pd.set_option('display.max_colwidth', -1)
final_docs = df['final_docs']
final_docs[3000:3020]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 16245    watched full white house press briefing since huckabee day surreal civil one four year abuse lie boring sometimes that's actually good thing people work without worrying personally attacked
# 16246    @ianhowardmann looooooong month huckabee held presser
# 16247    @danpfeiffer true difference huckabee mcenany ... like new tesla v high milage chevrolet malibu
# 16248    @radioguychris forgotten press briefing miss sarah huckabee
# 16251    @highwayjill @bjornbecker @projectlincoln amen brother spicer huckabee ho know name pretty face brain
# 16254    huckabee we're going impeach trump better impeach kamala harris bailing blm rioter
# 16255    love sarah huckabee sander ... great american
# 16256    @sethabramson sarah huckabee's version included serious stink eye
# 16257    huckabee we're going impeach trump better impeach kamala harris bailing blm rioter
# 16258    @andrade @lisacadag @cbsnews trump's lackey lied time maybe thing would different spicey huckabee's daughter mcelninny
# 16259    deceitful lying press secretary world sean spicer sarah huckabee sander kayleigh mcenany kellyanne conway straight lier
# 16261    sarah huckabee sander kayleigh mcenany trump's enthusiastic cleanup crew #smartnews
# 16264    mike huckabee biden could show unity healing stern rebuke impeachment social medium company via @mediaite show unity apologize
# 16265    every single person trump administration spouted lie curry favor president one biggest offender kayleigh mcenany kellyanne conway sarah huckabee sander
# 16266    @chadgilmartinca @kayleighmcenany @whitehouse @dougmillsnyt funny spent time lying dodging question attacking reporter job lying set new low wh press secretary incompetent huckabee biggest crowd history spicer competition
# 16268    @alexhammers prefaced lighter note psaki answer said talk policy executive order grace say great question instead scolding question like spicer huckabee mcenany
# 16270    i'm sorry sir golden corral closed also fuck @govmikehuckabee serial killer son lying monster daughter btw governor anymore
# 16272    sarah huckabee sander kayleigh mcenany trump's enthusiastic cleanup crew #smartnews
# 16277    jen psaki sarah huckabee sander sweet smell balsam pine cedar scented candle stench sulfur thank @presssec bringing honor decency back position wh press secretary
# 16279    @franklin_graham @tbn @govmikehuckabee found footage huckabee laughing immigrant
# Name: final_docs, dtype: object

# %%
#create document term matrix with TFIDF

#import vectorizing tool (usee TFIDF)
from sklearn.feature_extraction.text import TfidfVectorizer
# set max_features to 2000 (specifies the number of most frequently occurring words for which we want to create feature vectors)
# set min_df to 5 (word must occur in at least 5 documents)
# set max_df to 0.85 (word must not occur in more than 85 percent of the documents) 

tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.85, ngram_range=(1, 2), stop_words='english')  
doc_term_matrix_1 = tfidfconverter.fit_transform(df['final_docs'].values.astype('U'))

# %%
#run NMF model 

#import NMF tool 
from sklearn.decomposition import NMF

nmf_model = NMF(n_components=6)
nmf_Z = nmf_model.fit_transform(doc_term_matrix_1)

# %%
# run LDA model

#import LDA tool 
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 5, max_iter=40, learning_method='online', learning_decay=.5)
lda_Z = lda_model.fit_transform(doc_term_matrix_1)

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model:")
print_topics(lda_model, tfidfconverter )
print("=" * 30)
 
print("NMF Model:")
print_topics(nmf_model, tfidfconverter )
print("=" * 30)
# Out:
# LDA Model:
# Topic 0:
# [('sarah', 52.381785338837524), ('sarah huckabee', 50.42687647198881), ('sander', 45.361562704555844), ('realtuckfrumper', 43.66322001992715), ('huckabee sander', 43.131185111906476), ('brandonstraka', 33.77145605604785), ('sarahhuckabee', 22.9894075748786), ('trump', 22.10249640282913), ('press', 21.669105104107075), ('forget', 20.6675240571816)]
# Topic 1:
# [('biden', 38.869903216945886), ('day', 36.768820142594464), ('press', 28.551704838205286), ('democrat', 25.712688425823128), ('mike', 25.416057686419336), ('mike huckabee', 25.168587815901798), ('disaster', 22.708071042548575), ('huckabee day', 22.455440520191548), ('president', 22.36929524365562), ('day biden', 22.126173856758292)]
# Topic 2:
# [('mike', 69.92748500249498), ('mike huckabee', 68.42508066231123), ('youtube', 37.82954945847945), ('huckabee youtube', 34.889133428879944), ('left', 33.93972988641999), ('travis_huckabee', 32.973692122716514), ('govmikehuckabee', 27.43458182987372), ('successfully', 25.069214003981422), ('unit', 22.030103659786324), ('unit successfully', 22.030103659786324)]
# Topic 3:
# [('harris', 93.69582549722823), ('kamala', 92.64539303800483), ('mike', 91.16160654194448), ('kamala harris', 89.213022233809), ('mike huckabee', 87.65583290860638), ('blm', 60.620455277163586), ('bailing', 58.39813395350202), ('impeaching', 58.2662304796509), ('impeaching kamala', 56.55640629059548), ('bailing blm', 55.63487678842061)]
# Topic 4:
# [('sarah', 155.57355028513015), ('sarah huckabee', 151.4383317684368), ('sander', 135.6976099850798), ('huckabee sander', 134.05850712547203), ('spicer', 67.30903575074042), ('arkansas', 65.81488944410448), ('governor', 59.716862069834114), ('mcenany', 51.13568436096324), ('kayleigh', 43.774271243509695), ('spicer huckabee', 39.32602060978349)]
# ==============================
# NMF Model:
# Topic 0:
# [('sarah huckabee', 1.9829460123956693), ('sarah', 1.9610842698397721), ('huckabee sander', 1.857229959549638), ('sander', 1.835656747056884), ('realtuckfrumper', 0.3414022278019279), ('brandonstraka', 0.22527458391336416), ('like', 0.15246971790511818), ('look', 0.12614809276424846), ('like sarah', 0.10814797544580598), ('remember', 0.10640591478191443)]
# Topic 1:
# [('kamala harris', 0.8931534651636255), ('kamala', 0.8924550871118012), ('harris', 0.8908135733283354), ('impeaching kamala', 0.8818238776155858), ('float', 0.8772095091016653), ('huckabee float', 0.8768760106913973), ('impeaching', 0.870580055065616), ('bailing', 0.8396533490423918), ('bailing blm', 0.8272901121387047), ('blm', 0.827172473440701)]
# Topic 2:
# [('disaster', 0.921750766151838), ('disaster democrat', 0.9216018086074356), ('biden disaster', 0.9216018086074356), ('day biden', 0.9207490059069457), ('huckabee day', 0.9183887633164658), ('democrat', 0.861788348895197), ('day', 0.8563578520467937), ('biden', 0.8399098091067898), ('democrat westjournalism', 0.785525737157961), ('westjournalism', 0.6868292045616097)]
# Topic 3:
# [('governor', 1.5074479959952731), ('arkansas', 1.4561281739828709), ('run', 0.9968031586669625), ('governor arkansas', 0.9331056321543729), ('sander run', 0.7525372360158488), ('running', 0.6875544262563479), ('run governor', 0.6557659203724132), ('arkansas governor', 0.6003179877959275), ('running governor', 0.5702266408701682), ('run arkansas', 0.45841706338522187)]
# Topic 4:
# [('mike', 1.5642296214962403), ('mike huckabee', 1.5423338914601559), ('successfully', 0.33766139860801286), ('unit', 0.3085586711180532), ('unit successfully', 0.3085586711180532), ('say', 0.30035858957744777), ('trump', 0.2722146223532291), ('harris', 0.26996143195462263), ('kamala', 0.26395585429723095), ('kamala harris', 0.2568851238683853)]
# Topic 5:
# [('spicer', 1.1209898969178487), ('mcenany', 0.7787583378361603), ('sean', 0.6567295819885535), ('press', 0.6461700864905496), ('sean spicer', 0.6445783519543992), ('spicer huckabee', 0.5792524787741788), ('kayleigh', 0.5469310256982864), ('press secretary', 0.5028063829276035), ('secretary', 0.5015426189455983), ('spicer sarah', 0.450253914174458)]
# ==============================

# %%
# cross-validation to find best parameters for LDA model

#import cross-validation tool
from sklearn.model_selection import GridSearchCV

# define search parameters
search_params = {'n_components': [5, 8, 10, 12], 'learning_decay': [.5, .7, .9]}

# initialize model for cross-validation
lda = LatentDirichletAllocation()

# initialize grid search class 
model = GridSearchCV(lda, param_grid=search_params)

# run grid search 
model.fit(doc_term_matrix_1)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 8, 10, 12]})

# %%
# what is best model? 
best_lda_model = model.best_estimator_

# print parameters for best model
print("Parameters for best model: ", model.best_params_)

# print log likelihood score
print("Log likelihood score of best model: ", model.best_score_)

# print perplexity score
print("Perplexity score of best model: ", best_lda_model.perplexity(doc_term_matrix_1))
# Out:
# Parameters for best model:  {'learning_decay': 0.5, 'n_components': 5}
# Log likelihood score of best model:  -27756.90461543678
# Perplexity score of best model:  2173.1791414949594

# %%
topic_values = lda_model.transform(doc_term_matrix_1)
df['LDA_topic'] = topic_values.argmax(axis=1)

# %%
df['text'][df.LDA_topic ==0][1000:1050]
# Out:
# 20252    @AnaCabrera Hogan Gidley is the Sarah Huckabee Sanders of 2021.
# 20374    For me Sarah Huckabee is one of our most shining leaders in America First Populism.  Love your values, Sarah!  Run for Governor.
# 20453    The REAL DONALD TRUMP The Media Won't Tell You About! | Sarah Huckabee S... https://t.co/eCXUwCNkn5 via @YouTube
# 20495    @GovMikeHuckabee @donmclean @HuckabeeOnTBN Mr. Huckabee, to see you compare Jeffry Dahmar  to anything much less trump is sick. You are looked up to as a Christian. How can you stand by the lies of Donald Trump. Totally looses me. PS Hello from Texarkana 🙄
# 20498    @J_Mei21 @KimKimbowman @kayleighmcenany They all did! \nSean Spicer \nThe Mooch ( not for long)\nSarah Huckabee Sanders\nKellyanne Conway
# 20612    This video gets better every day. \n\n(Lisa 'Friends' Kudrow channeling Kellyanne Conway &gt;&gt; Keighley McEnany &gt;&gt; Sarah Huckabee, from Netflix #deathto2020 ) \n\nhttps://t.co/K93Tnhfwle
# 20665    @LouDobbs Does Huckabee know his thin career depends on Trump supporters? Bashing Trump will end his little gig! Too bad for Sarah too.
# 20671    From the Get go I've Always Thought Sarah Huckabee Sanders looked like Michael Ian Black in Drag. https://t.co/jhfq1RIbSb
# 20693    @politvidchannel He's showing off then because @ksorbs , @kirstiealley , @kilmeade , and Sarah Huckabee Sanders were only complaining of losing 40,000 to 50,000.
# 20699    Anyone know if Sarah Huckabee Sanders is still planning on running for Arkansas Governor or not?
