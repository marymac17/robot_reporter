# %%
#import initial libraries

import pandas as pd
import numpy as np

# %%
#import data 

df = pd.read_csv("data/rihanna.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1544143 entries, 0 to 1544142
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   id                            1544143 non-null  int64
#  1   tweet_url                     1544143 non-null  object
#  2   created_at                    1544143 non-null  object
#  3   parsed_created_at             1544143 non-null  object
#  4   user_screen_name              1544143 non-null  object
#  5   text                          1544143 non-null  object
#  6   tweet_type                    1544143 non-null  object
#  7   coordinates                   13 non-null       object
#  8   hashtags                      573385 non-null   object
#  9   media                         218907 non-null   object
#  10  urls                          110688 non-null   object
#  11  favorite_count                1544143 non-null  int64
#  12  in_reply_to_screen_name       333413 non-null   object
#  13  in_reply_to_status_id         318620 non-null   float64
#  14  in_reply_to_user_id           333416 non-null   float64
#  15  lang                          1544143 non-null  object
#  16  place                         8905 non-null     object
#  17  possibly_sensitive            318222 non-null   object
#  18  retweet_count                 1544143 non-null  int64
#  19  retweet_or_quote_id           1152620 non-null  float64
#  20  retweet_or_quote_screen_name  1152620 non-null  object
#  21  retweet_or_quote_user_id      1152620 non-null  float64
#  22  source                        1543592 non-null  object
#  23  user_id                       1544143 non-null  int64
#  24  user_created_at               1544143 non-null  object
#  25  user_default_profile_image    1544143 non-null  bool
#  26  user_description              1161777 non-null  object
#  27  user_favourites_count         1544143 non-null  int64
#  28  user_followers_count          1544143 non-null  int64
#  29  user_friends_count            1544143 non-null  int64
#  30  user_listed_count             1544143 non-null  int64
#  31  user_location                 914694 non-null   object
#  32  user_name                     1543872 non-null  object
#  33  user_statuses_count           1544143 non-null  int64
#  34  user_time_zone                0 non-null        float64
#  35  user_urls                     192435 non-null   object
#  36  user_verified                 1544143 non-null  bool
# dtypes: bool(2), float64(5), int64(9), object(21)
# memory usage: 415.3+ MB

# %%
# count number of languages in data set

count_lang = df['lang'].unique()
print(len(count_lang), count_lang)
# Out:
# 54 ['en' 'hi' 'pt' 'th' 'und' 'in' 'tl' 'pa' 'es' 'et' 'mr' 'ca' 'ta' 'bn'
#  'zh' 'is' 'ja' 'de' 'ht' 'my' 'lv' 'fr' 'ur' 'it' 'fi' 'pl' 'gu' 'ne'
#  'ko' 'lt' 'cy' 'no' 'tr' 'sl' 'nl' 'kn' 'te' 'da' 'hu' 'ml' 'sv' 'vi'
#  'ro' 'ar' 'el' 'eu' 'fa' 'cs' 'ru' 'or' 'am' 'uk' 'sr' 'iw']

# %%
# tweets are in 54 different languages

# I'll be working only with Tweets in English
# drop tweets in all other languages
# now working with 1199289 Tweets 

df = df[df.lang == 'en']
df.shape
# Out:
# (1199289, 37)

# %%
# drop unnecessary columns (everything but 'text' and 'parsed_created_at')
df = df.drop(['id', 'tweet_url', 'created_at',
       'user_screen_name', 'tweet_type', 'coordinates', 'hashtags',
       'media', 'urls', 'favorite_count', 'in_reply_to_screen_name',
       'in_reply_to_status_id', 'in_reply_to_user_id', 'lang', 'place',
       'possibly_sensitive', 'retweet_count', 'retweet_or_quote_id',
       'retweet_or_quote_screen_name', 'retweet_or_quote_user_id', 'source',
       'user_id', 'user_created_at', 'user_default_profile_image',
       'user_description', 'user_favourites_count', 'user_followers_count',
       'user_friends_count', 'user_listed_count', 'user_location', 'user_name',
       'user_statuses_count', 'user_time_zone', 'user_urls', 'user_verified'], axis=1)

# %%
# check end time & date of data

df.iloc[0]

# first Tweet downloaded 2021-02-04 02:11:22+00:00
# Out:
# parsed_created_at                            2021-02-04 02:11:22+00:00
# text                 @rihanna India is capable of solving all its p...
# Name: 0, dtype: object

# %%
# check start time & date of data 

df.iloc[-1]

# last Tweet on 22021-02-02 17:12:19+00:00
# Out:
# parsed_created_at               2021-02-02 17:12:19+00:00
# text                 @notevenbitfunny @rihanna Hmmmm done
# Name: 1544142, dtype: object

# %%
df.head(20)
# Out:
#             parsed_created_at  \
# 0   2021-02-04 02:11:22+00:00
# 2   2021-02-04 02:11:22+00:00
# 3   2021-02-04 02:11:22+00:00
# 4   2021-02-04 02:11:22+00:00
# 5   2021-02-04 02:11:22+00:00
# 7   2021-02-04 02:11:22+00:00
# 8   2021-02-04 02:11:22+00:00
# 9   2021-02-04 02:11:22+00:00
# 10  2021-02-04 02:11:22+00:00
# 12  2021-02-04 02:11:21+00:00
# 14  2021-02-04 02:11:21+00:00
# 17  2021-02-04 02:11:21+00:00
# 18  2021-02-04 02:11:21+00:00
# 19  2021-02-04 02:11:21+00:00
# 20  2021-02-04 02:11:21+00:00
# 21  2021-02-04 02:11:20+00:00
# 22  2021-02-04 02:11:20+00:00
# 23  2021-02-04 02:11:20+00:00
# 24  2021-02-04 02:11:20+00:00
# 25  2021-02-04 02:11:20+00:00
#
#                                                  text
# 0   @rihanna India is capable of solving all its p...
# 2   So, singer Rihanna &amp; ex porn star Mia Khal...
# 3   Rihanna once said “Please don’t stop the music...
# 4   @SidraIND @Profdilipmandal @rihanna Chal be bj...
# 5   @rihanna What is your objection to the new law...
# 7   I told u! Bhade ki tattu @rihanna must have ch...
# 8   The PM of India openly campaigning for Trump w...
# 9   BIG EXPOSE ON @GretaThunberg @miakhalifa @riha...
# 10  The awareness @rihanna, @GretaThunberg have br...
# 12  No farmers, no food. All over in the world far...
# 14      @rihanna Thank you Rihanna stand with farmers
# 17   Farmers will win! ✊🏻\n\n#FarmersProtest #Rihanna
# 18  @AdilAkh14018608 Because Rihanna raised her vo...
# 19  All these Indian big shot celebs remained mute...
# 20  Much love @rihanna ✊✊✊\n#FarmersProtest #farme...
# 21  For any movement or a cause, amplification of ...
# 22  What Rihanna, Mia or Greta feel, is irrelevant...
# 23  My favorite Rihanna song:\n\n'Love the way you...
# 24  Very bad! The Indian News channels are showing...
# 25  We have our own Indian @rihanna Renee Kujur. B...

# %%
df[300000:300010]
# Out:
#                 parsed_created_at  \
# 376004  2021-02-03 15:56:29+00:00
# 376005  2021-02-03 15:56:29+00:00
# 376008  2021-02-03 15:56:29+00:00
# 376009  2021-02-03 15:56:28+00:00
# 376012  2021-02-03 15:56:28+00:00
# 376013  2021-02-03 15:56:28+00:00
# 376015  2021-02-03 15:56:28+00:00
# 376016  2021-02-03 15:56:28+00:00
# 376017  2021-02-03 15:56:28+00:00
# 376018  2021-02-03 15:56:28+00:00
#
#                                                      text
# 376004  .@rihanna exposed the whole BJP’s IT Cell with...
# 376005  Can't wait for the collaboration of these two ...
# 376008  So, singer Rihanna &amp; ex porn star Mia Khal...
# 376009  Rihanna: Pop Star.\nMia Khalifa: Porn Star.\nP...
# 376012  @rajstar30 @shadyfenty_ @rihanna It’s called r...
# 376013   Republic of Rihanna is trending in social media.
# 376015  Meanwhile the real farmers of India\nRihanna who?
# 376016  Rihanna has raised her voice for social justic...
# 376017  #IndiaAgainstPropaganda | Last week we had IMF...
# 376018  #Rihanna at farmers protest https://t.co/3zHni...

# %%
# tokenize, remove stopwords, remove urls, lowercase, remove punctuation, remove numbers

# import necessary libraries: ntlk etc.

import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 

# create variable for "text" column 
text = df['text'] 


stop = stopwords.words('english')

punc = list(set(string.punctuation))

def tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_url(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r'', text)

def process_text(text):
    text = remove_url(text)
    text = tokenizer(text)
    text = [word.lower() for word in text]
    text = [re.sub('[0-9]+', '', word) for word in text]
    text = [word for word in text if word not in punc]
    text = [word for word in text if word not in stop]
    text = [each for each in text if len(each) > 1]
    text = [word for word in text if ' ' not in word]
     
    return text

# %%
# apply text processing functions to text

df['processed_text'] = df['text'].apply(process_text)

# %%
# part-of-speech tagging 

ready_for_pos = df['processed_text']

def pos_tagging(text):
    pos_tag = [pos_tag(word) for word in ready_for_pos]

df['pos_tagged'] = df.processed_text.apply(lambda x: pos_tag(x))

# %%
# lemmatizing
pos_tagged = df['pos_tagged']

from nltk.stem import WordNetLemmatizer 
wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
# look at lemmatized text

df['lemmatized'] = lemmatized
lemmatized[:20]
# Out:
# [['@rihanna',
#   'india',
#   'capable',
#   'solving',
#   'problem',
#   'always',
#   'foreign',
#   'anti-india',
#   'element',
#   'interfere',
#   'middle',
#   'even',
#   'know',
#   'farming',
#   'farmer',
#   'protesting',
#   'indian',
#   'responsible',
#   'solving',
#   'problem',
#   'farmer'],
#  ['singer',
#   'rihanna',
#   'ex',
#   'porn',
#   'star',
#   'mia',
#   'khalifa',
#   'know',
#   'imf',
#   'economist',
#   'gita',
#   'gopinath',
#   'swaminathan',
#   'farm',
#   'law',
#   'gita',
#   'good',
#   'kerala',
#   'communist',
#   "cm's",
#   'advisor',
#   'bhakt',
#   'greta',
#   'thunberg',
#   'support',
#   'farm',
#   'union',
#   'want',
#   'scrap',
#   'ordinance',
#   'stubble',
#   'burning'],
#  ['rihanna', 'said', 'please', 'stop', 'music', 'think', 'hypocritical'],
#  ['@sidraind', '@profdilipmandal', '@rihanna', 'chal', 'bjp', 'ki'],
#  ['@rihanna', 'objection', 'new', 'law', 'idea', 'tweeting', 'sake'],
#  ['told',
#   'bhade',
#   'ki',
#   'tattu',
#   '@rihanna',
#   'must',
#   'charged',
#   'half',
#   'million',
#   'tweet',
#   'whole',
#   'fake',
#   'trend',
#   'would',
#   'cost',
#   'atleast',
#   'million',
#   'usd',
#   'organizer',
#   'highly',
#   'paid',
#   'influencers',
#   'cnn',
#   'article',
#   'wonder',
#   'power',
#   'could',
#   'afford',
#   'would',
#   'benefit',
#   '#fakefarmerprotest'],
#  ['pm',
#   'india',
#   'openly',
#   'campaigning',
#   'trump',
#   'abki',
#   'baar',
#   'trump',
#   'sarkar',
#   'interference',
#   'internal',
#   'affair',
#   'u',
#   'rihanna',
#   'greta',
#   'airing',
#   'personal',
#   'opinion',
#   'indian',
#   'farmer',
#   'external',
#   'interference',
#   "that's",
#   '#bhaktlogic',
#   "that's",
#   '#modiglobaldisaster'],
#  ['big',
#   'expose',
#   '@gretathunberg',
#   '@miakhalifa',
#   '@rihanna',
#   'funding',
#   'connection',
#   'khalistan',
#   'supporter',
#   'org'],
#  ['awareness',
#   '@rihanna',
#   '@gretathunberg',
#   'brought',
#   "india's",
#   '#farmersprotest',
#   'great',
#   'praise',
#   'support',
#   'resource',
#   'go',
#   'brave',
#   'sikh',
#   'farmer',
#   'activist',
#   'organizer',
#   'journalist',
#   'others',
#   'ground',
#   'india',
#   'marching',
#   'since',
#   'august',
#   'right'],
#  ['farmer',
#   'food',
#   'world',
#   'farmer',
#   'affected',
#   '#climatechange',
#   'must',
#   'stand',
#   'solidarity',
#   'support',
#   '#farmersprotests',
#   'said',
#   '@kaohua',
#   '@rihanna',
#   '@licypriyak',
#   '@vanessa_vash',
#   '@gretathunberg',
#   '@wfp_fr',
#   '@ifadpresident',
#   '@wholefoods',
#   '@ifad'],
#  ['@rihanna', 'thank', 'rihanna', 'stand', 'farmer'],
#  ['farmer', 'win', '#farmersprotest', '#rihanna'],
#  ['@adilakh',
#   'rihanna',
#   'raised',
#   'voice',
#   'exploited',
#   'sachin',
#   'tendulkar',
#   'stand',
#   'exploiter'],
#  ['indian',
#   'big',
#   'shot',
#   'celebs',
#   'remained',
#   'mute',
#   'protesting',
#   'farmer',
#   'walled',
#   'electricity',
#   'water',
#   'internet',
#   'cut',
#   'bjp',
#   'goon',
#   'brought',
#   'stone',
#   'suddenly',
#   'unmuted',
#   '@rihanna',
#   '@gretathunberg',
#   'spoke',
#   'spineless',
#   'heartless',
#   'sarkari',
#   'celebs'],
#  ['much', 'love', '@rihanna', '#farmersprotest', '#farmersrprotest'],
#  ['movement',
#   'cause',
#   'amplification',
#   'online',
#   'influencers',
#   'among',
#   'top',
#   'priority',
#   '#farmersprotest',
#   'get',
#   'rihanna',
#   'global',
#   'boost',
#   'time',
#   'negativity',
#   'seeping',
#   'movement',
#   'least',
#   'online',
#   'narrative',
#   'snowball',
#   'effect'],
#  ['rihanna',
#   'mia',
#   'greta',
#   'feel',
#   'irrelevant',
#   'india',
#   'stand',
#   'strong',
#   'india',
#   'stand',
#   'united',
#   'one',
#   'nation',
#   'one',
#   'purpose',
#   'one',
#   'goal',
#   'jai',
#   'hind',
#   '#indiaagainstpropaganda'],
#  ['favorite', 'rihanna', 'song', 'love', 'way', 'lie'],
#  ['bad',
#   'indian',
#   'news',
#   'channel',
#   'showing',
#   'rihanna',
#   'video',
#   'mia',
#   'khalifa',
#   'video',
#   'ye',
#   'bias',
#   'hai'],
#  ['indian',
#   '@rihanna',
#   'renee',
#   'kujur',
#   'media-film-glamour-culture',
#   'industry',
#   'casteist',
#   'obsessed',
#   'colourism',
#   'chhatisgarh',
#   'govt',
#   'make',
#   'state',
#   'brand',
#   'ambassador',
#   'shd',
#   'go',
#   'global',
#   '@rihannarenne',
#   '@bhupeshbaghel',
#   '@chhotu_vasava',
#   '@hansrajmeena']]

# %%
# before vectorizing, cast lists of words back into strings

df['final_docs'] = df['lemmatized'].apply(lambda x: " ".join(x))
pd.set_option('display.max_colwidth', -1)
final_docs = df['final_docs']
final_docs[3000:3020]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 3874    #satire dear #rihanna effort destabilise india mansion london force u snatch umbrella ella ella eh eh away writes @purba_ray
# 3875    rihanna said please stop music think hypocritical
# 3876    country proud farmer know important trust addressed soon need outsider poking nose internal matter @miakhalifa @gretathunberg @rihanna
# 3877    thank #rihanna giving chance spineless indian celebrity expose #farmersprotests #istandwithfarmers
# 3879    truth singer rihanna's tweet farmer protest propaganda fully exposed
# 3882    big expose @gretathunberg @miakhalifa @rihanna funding connection khalistan supporter org
# 3883    much love @rihanna #farmersprotest #farmersrprotest
# 3884    rihanna pop star mia khalifa porn star pappu twinkle twinkle little star @republic_bharat #indiatogether #indiaagainstpropaganda
# 3885    still sure took bop need answer @rihanna
# 3886    dear sachin india's sovereignty rest people constitution start people india foreigner can't take away careful govt also wish spoken farmer rihanna #farmersprotest
# 3887    rihanna indian government shook need album uplift oppressed love see #farmersprostest
# 3888    @shefvaidya @gretathunberg @rihanna @miakhalifa @rahulgandhi @vivekagnihotri @kanganateam @pakalupaipto @tajinderbagga @tarekfatah @voice_for_india @imfnews @bjpindia #indiaagainstpropaganda #modi #modiwithfarmers found pic prove many ppl wrong look hardcore farmer
# 3889    rihanna's worth kangana's worth rupee
# 3890    stand solidarity #farmersprotest india thank speaking @rihanna
# 3895    within hour rihanna's tweet diljit drop song dedicated rihanna chronology samajh rahe ho everything pre-planned #indiawithmodi #indiastandstogether #indiaagaistpropoganda
# 3896    @jazzyb speaking rihanna tweet ... month se inke muh nhi khule .. ab apne apne bill se nikal rhe ... shame ... stop calling hero
# 3899    @rihanna thanks standing farmer
# 3900    rihanna indian government shook need album uplift oppressed love see #farmersprostest
# 3901    rihanna said please stop music think hypocritical
# 3902    thank @rihanna consistently uplifting empowering voice oppressed
# Name: final_docs, dtype: object

# %%
#create document term matrix with TFIDF

#import vectorizing tool (usee TFIDF)
from sklearn.feature_extraction.text import TfidfVectorizer
# set max_features to 2000 (specifies the number of most frequently occurring words for which we want to create feature vectors)
# set min_df to 5 (word must occur in at least 5 documents)
# set max_df to 0.85 (word must not occur in more than 85 percent of the documents) 

tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.85, ngram_range=(1, 2), stop_words='english')  
doc_term_matrix_1 = tfidfconverter.fit_transform(df['final_docs'].values.astype('U'))

# %%
#run NMF model 

#import NMF tool 
from sklearn.decomposition import NMF

nmf_model = NMF(n_components=6)
nmf_Z = nmf_model.fit_transform(doc_term_matrix_1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_nmf.py:1077: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   " improve convergence." % max_iter, ConvergenceWarning)

# %%
# run LDA model

#import LDA tool 
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 8, max_iter=10, learning_method='online', learning_decay=.7)
lda_Z = lda_model.fit_transform(doc_term_matrix_1)

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model:")
print_topics(lda_model, tfidfconverter )
print("=" * 30)
 
print("NMF Model:")
print_topics(nmf_model, tfidfconverter )
print("=" * 30)
# Out:
# LDA Model:
# Topic 0:
# [('matter', 9309.907590422066), ('farmersprotest rihanna', 8694.357517245258), ('farmer', 8057.700416525812), ('indian farmer', 7826.489406724789), ('farmersprotest', 6548.5385128472735), ('indian', 5665.681446464728), ('internal matter', 5089.935442951565), ('win', 5000.553400621397), ('internal', 4955.392557467628), ('shame', 4697.19056273759)]
# Topic 1:
# [('kangana', 12577.792485014226), ('like', 11284.979762900759), ('magazine', 11277.915119635316), ('protest', 10493.876279868693), ('tweet', 8517.634150499327), ('farmer', 8171.927557577461), ('rihanna farmersprotest', 7948.142098624652), ('farmersprotest', 7886.076096957072), ('farmer protest', 7793.424378708886), ('talk', 6924.811057978434)]
# Topic 2:
# [('essence', 11362.909583026965), ('rihanna essence', 11289.439848866148), ('essence magazine', 11270.41610220002), ('know', 10505.81630813991), ('farm', 7443.5674232645715), ('rihanna know', 6269.013569157268), ('farm law', 5175.311514554905), ('law', 4745.8691435901965), ('dear', 3756.8506908422114), ('bhakt', 3088.399298901764)]
# Topic 3:
# [('tweet', 18948.914094496875), ('india', 15477.513134716117), ('indian', 12826.502166671036), ('farmer', 10912.11631614097), ('modi', 9822.056352688696), ('farmersprotest', 9177.449271505368), ('need', 9158.963775528284), ('people', 8677.786362366536), ('world', 8300.362045955453), ('bjp', 8166.889070906421)]
# Topic 4:
# [('talking', 8729.11356047283), ('music', 5943.582372845006), ('rihanna talking', 5846.021987665331), ('stop', 5740.626094338681), ('pragyanojha', 5392.353051861508), ('think', 5123.98490441762), ('trying', 5079.6785098815335), ('pragyanojha rihanna', 5062.398370754621), ('fool', 4928.792935094022), ('yes', 4832.337134995058)]
# Topic 5:
# [('thank', 19543.620208865217), ('rihanna thank', 12243.036870136099), ('thanks', 10768.287864479264), ('love', 9168.13830387878), ('support', 8766.662555018276), ('thank rihanna', 8601.034383764216), ('rihanna rihanna', 8111.15546323871), ('rihanna thanks', 7824.622292245288), ('india', 7544.145669311382), ('farmersprotest', 7100.48416775865)]
# Topic 6:
# [('right', 8357.529675835074), ('kanganateam', 6504.04693178589), ('nigarnawab', 5932.709285564952), ('rihanna nigarnawab', 5929.682007297255), ('cell right', 5440.124681145055), ('kanganateam rihanna', 5231.289164676722), ('nigarnawab cell', 5051.870458287124), ('queen', 4854.549980129828), ('cell', 4826.656213378035), ('understand', 4757.732794079473)]
# Topic 7:
# [('paid', 5469.367749057628), ('support farmersprotest', 4417.444056278879), ('rihanna love', 3533.8238098919055), ('agitation', 3168.7405386172145), ('connection', 2722.097129044873), ('job', 2578.621839703625), ('opinion', 2567.986295424598), ('world', 2379.8861081381483), ('violence', 2337.6532372348674), ('alexa', 2307.2857860657414)]
# ==============================
# NMF Model:
# Topic 0:
# [('farmersprotest', 5.5362245767030664), ('thank', 5.018287130590454), ('farmer', 3.0810375957190397), ('indian', 2.7143620080834836), ('rihanna thank', 2.644330420502332), ('thank rihanna', 2.593826292366465), ('support', 2.507736467340161), ('india', 2.3520173753658935), ('farmersprotest rihanna', 2.1296525389658414), ('gretathunberg', 1.7942412575937527)]
# Topic 1:
# [('india stand', 3.4809002054544855), ('stand', 3.343537888463313), ('india', 2.97249605413165), ('mia', 1.937790227461768), ('indiaagainstpropaganda', 1.8215425751026202), ('rihanna mia', 1.7982536872923038), ('united', 1.7937291829895203), ('stand united', 1.7872946887073164), ('jai', 1.7615814416759417), ('mia greta', 1.749110851326938)]
# Topic 2:
# [('know', 8.084445775712776), ('right', 2.1408144533984244), ('rihanna know', 2.056956803175176), ('know farmer', 1.2557983336781007), ('kangana', 1.173095415667249), ('talking', 1.1595050765499353), ('human', 1.0958704646011057), ('human right', 1.0894802326551931), ('na', 1.0590393892990173), ('kangana know', 1.018370370612191)]
# Topic 3:
# [('essence', 5.239449857193729), ('rihanna essence', 5.225858597801171), ('essence magazine', 5.211127195970419), ('magazine', 5.205661082150473), ('check', 0.023446499019315118), ('thank', 0.011669363285543143), ('artist', 0.009327364351174839), ('new', 0.005736433289140927), ('issue', 0.005371405414512142), ('taylor swift', 0.004262947053995507)]
# Topic 4:
# [('tweet', 5.494247702462186), ('protest', 4.009051618864555), ('farmer protest', 3.518681279723154), ('farmer', 3.4200811281002643), ('rihanna tweet', 2.4626236318898433), ('tweet farmer', 2.204325494216368), ('paid', 2.101363077158355), ('stop', 1.6354242064545645), ('stop music', 1.6292096031031627), ('music', 1.624627410200435)]
# Topic 5:
# [('matter', 2.6191733537298276), ('internal', 2.509913823106733), ('internal matter', 2.4510177915719282), ('need', 2.2256348784256286), ('country', 2.093120831909213), ('nose', 2.042384649701413), ('poking', 1.9975077774748413), ('poking nose', 1.9893719096789346), ('outsider', 1.98714556607307), ('nose internal', 1.986426243193116)]
# ==============================
