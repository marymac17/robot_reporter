# %% [markdown]
# # Part 1: Data import and cleaning

# %%
#import initial libraries

import pandas as pd
import numpy as np

# %%
#import data, retweets already removed using Twarc

df = pd.read_csv("data/nike_NR.csv")

# %%
# look at data
df.info()
#130531 Tweets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130531 entries, 0 to 130530
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            130531 non-null  int64
#  1   tweet_url                     130531 non-null  object
#  2   created_at                    130531 non-null  object
#  3   parsed_created_at             130531 non-null  object
#  4   user_screen_name              130531 non-null  object
#  5   text                          130531 non-null  object
#  6   tweet_type                    130531 non-null  object
#  7   coordinates                   350 non-null     object
#  8   hashtags                      19650 non-null   object
#  9   media                         31251 non-null   object
#  10  urls                          37673 non-null   object
#  11  favorite_count                130531 non-null  int64
#  12  in_reply_to_screen_name       55529 non-null   object
#  13  in_reply_to_status_id         53498 non-null   float64
#  14  in_reply_to_user_id           55529 non-null   float64
#  15  lang                          130531 non-null  object
#  16  place                         3004 non-null    object
#  17  possibly_sensitive            51720 non-null   object
#  18  retweet_count                 130531 non-null  int64
#  19  retweet_or_quote_id           7171 non-null    float64
#  20  retweet_or_quote_screen_name  7171 non-null    object
#  21  retweet_or_quote_user_id      7171 non-null    float64
#  22  source                        130371 non-null  object
#  23  user_id                       130531 non-null  int64
#  24  user_created_at               130531 non-null  object
#  25  user_default_profile_image    130531 non-null  bool
#  26  user_description              116211 non-null  object
#  27  user_favourites_count         130531 non-null  int64
#  28  user_followers_count          130531 non-null  int64
#  29  user_friends_count            130531 non-null  int64
#  30  user_listed_count             130531 non-null  int64
#  31  user_location                 85059 non-null   object
#  32  user_name                     130526 non-null  object
#  33  user_statuses_count           130531 non-null  int64
#  34  user_time_zone                0 non-null       float64
#  35  user_urls                     50474 non-null   object
#  36  user_verified                 130531 non-null  bool
# dtypes: bool(2), float64(5), int64(9), object(21)
# memory usage: 35.1+ MB

# %%
# count number of languages in data set

count_lang = df['lang'].unique()
print(len(count_lang), count_lang)
# Out:
# 53 ['en' 'ja' 'und' 'es' 'fr' 'pt' 'pl' 'tl' 'hi' 'ht' 'de' 'in' 'nl' 'tr'
#  'ko' 'et' 'ar' 'no' 'fi' 'it' 'is' 'ca' 'sl' 'sv' 'da' 'th' 'fa' 'ru'
#  'zh' 'ro' 'cs' 'eu' 'cy' 'hu' 'lv' 'el' 'vi' 'uk' 'lt' 'iw' 'ta' 'sr'
#  'mr' 'bg' 'lo' 'hy' 'pa' 'ne' 'am' 'ur' 'ml' 'si' 'te']

# %%
# tweets are in 53 different languages

# I'll be working only with Tweets in English
# drop tweets in all other languages
# now working with 58830 Tweets 

df = df[df.lang == 'en']
df.shape
# Out:
# (58830, 37)

# %%
# drop unnecessary columns 

df = df.drop(['tweet_url', 'created_at', 'media', 'urls','in_reply_to_screen_name',
       'in_reply_to_status_id', 'in_reply_to_user_id', 'retweet_or_quote_id',
       'retweet_or_quote_screen_name', 'retweet_or_quote_user_id', 'source',
       'user_created_at', 'user_name', 'user_verified', 'user_friends_count', 'user_listed_count',
       'user_statuses_count', 'user_default_profile_image', 'user_description',
       'user_favourites_count', 'user_followers_count', 'coordinates', 'lang', 'user_location', 'user_time_zone', 'user_urls', 'place'], axis=1)

# %%
# check start time & date of data

df.iloc[0]

# first Tweet 2021-01-13 18:46:48+00:00
# Out:
# id                                                  1349427695499816962
# parsed_created_at                             2021-01-13 18:46:48+00:00
# user_screen_name                                              DRUGZK1LL
# text                  Well sounds to me like ur bf is sick and fucki...
# tweet_type                                                        reply
# hashtags                                                            NaN
# favorite_count                                                        0
# possibly_sensitive                                                  NaN
# retweet_count                                                         0
# user_id                                             1303894143492673537
# Name: 0, dtype: object

# %%
# check end time & date of data 

df.iloc[-1]

# last Tweet 2021-01-06 23:38:56+00:00
# Out:
# id                                                  1346964499438448642
# parsed_created_at                             2021-01-06 23:38:56+00:00
# user_screen_name                                            NikeService
# text                  @CJ2Blessed Definitely not something we want t...
# tweet_type                                                        reply
# hashtags                                                            NaN
# favorite_count                                                        0
# possibly_sensitive                                                False
# retweet_count                                                         0
# user_id                                                        14462333
# Name: 130527, dtype: object

# %% [markdown]
# # Part 2: Text processing for NLP

# %%
# create variable for "text" column 
text = df['text']

# %%
# tokenize, remove stopwords, remove urls, lowercase, remove punctuation, remove numbers

# import necessary libraries: ntlk etc.

import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 


stop = stopwords.words('english')

punc = list(set(string.punctuation))

def tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_url(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r'', text)

def process_text(text):
    text = remove_url(text)
    text = tokenizer(text)
    text = [word.lower() for word in text]
    text = [re.sub('[0-9]+', '', word) for word in text]
    text = [word for word in text if word not in punc]
    text = [word for word in text if word not in stop]
    text = [each for each in text if len(each) > 1]
    text = [word for word in text if ' ' not in word]
     
    return text

# %%
# apply text processing functions to text

df['processed_text'] = df['text'].apply(process_text)

# %%
# look at some of processed text

pd.set_option('display.max_colwidth', -1)
df['processed_text'][:20]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0     [well, sounds, like, ur, bf, sick, fucking, tired, ur, lulu, leggings, birkenstocks, feet, ass, nike, pro, sports, bra, wearing, ass, like, girl, hes, bored, babe, hes, bored]
# 1     [@redbloodedguy, nike, use, slave, labor, china, different, use, slaves, us, early, th, century]
# 3     [sneaker, news, alert, nike, waffle, one, set, arrive, sleek, black, #upcomingsneakers, #nikewaffleone, #soledout, #trainers, #sneakers]
# 5     [@gosvenerwilliam, @anacabrera, @donwinslow, @nike, fed, lies, antifa, organization, per, se, know, acronym, antifa, means, fascism, know, corrupt, leaders, like, hitler, mussolini, fascists, father, fought, ww, antifa, trump, nature, fascist]
# 6     [honestly, really, fuck, nike, much, one, fuck, brand]
# 7     [@anacabrera, nike, support, lawmakers]
# 12    [neon, nike, outfit, people]
# 13    [@wtpnews, @sparkledocmad, bye, nike, sucks, days, anyway]
# 14    [@foxlyfe, @againcheeky, @anacabrera, @donwinslow, @nike, poor, snowflake]
# 15    [@denisewu, fact, nike, would, supporting, politicians, attempted, boycott, times, kind, surprising]
# 16    [#entertainmentcelebrity, check, notre, nike, dunk, high, blue, void, chicago-based, boutique, notre, nike, two, takes, dunk, high, set, drop, official, images, light, orewood, brown, style, revealed, last, week]
# 17    [@nike, @goretexna, cruzrones, would, nice, addition, rainy, pnw, days, trying, #makesportadailyhabit, ..., even, rain]
# 18    [@yungblackauteur, cj, said, personal, nike, trainer, thank]
# 19    [@anacabrera, wut, would, nike, supported, previously]
# 22    [success, nelly, nike, accounts]
# 23    [nike, definitely, needs, catch, wake]
# 24    [@ack, @anacabrera, another, win, nike, marketing, geniuses]
# 25    [@anacabrera, someday, people, going, realize, nike, different, people, early, th, century, used, slaves, grow, cotton]
# 26    [first, one, sharing, twitter, like, let, know, want, write, thread, @glossier, @nike, @lululemon, @lego_group, brand, like, next]
# 27    [@nike, @nikestore, morning, vented, frustration, regarding, app, stock, reaction, tweet, immediately, dealt, faith, nike, restored, thank, taking, every, customer, seriously, safe]
# Name: processed_text, dtype: object

# %%
# part-of-speech tagging 

ready_for_pos = df['processed_text']

def pos_tagging(text):
    pos_tag = [pos_tag(word) for word in ready_for_pos]

df['pos_tagged'] = df.processed_text.apply(lambda x: pos_tag(x))

# %%
# lemmatizing

pos_tagged = df['pos_tagged']

wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
# look at lemmatized text

df['lemmatized'] = lemmatized
lemmatized[:20]
# Out:
# [['well',
#   'sound',
#   'like',
#   'ur',
#   'bf',
#   'sick',
#   'fucking',
#   'tired',
#   'ur',
#   'lulu',
#   'legging',
#   'birkenstocks',
#   'foot',
#   'as',
#   'nike',
#   'pro',
#   'sport',
#   'bra',
#   'wearing',
#   'as',
#   'like',
#   'girl',
#   'he',
#   'bored',
#   'babe',
#   'he',
#   'bored'],
#  ['@redbloodedguy',
#   'nike',
#   'use',
#   'slave',
#   'labor',
#   'china',
#   'different',
#   'use',
#   'slave',
#   'u',
#   'early',
#   'th',
#   'century'],
#  ['sneaker',
#   'news',
#   'alert',
#   'nike',
#   'waffle',
#   'one',
#   'set',
#   'arrive',
#   'sleek',
#   'black',
#   '#upcomingsneakers',
#   '#nikewaffleone',
#   '#soledout',
#   '#trainers',
#   '#sneakers'],
#  ['@gosvenerwilliam',
#   '@anacabrera',
#   '@donwinslow',
#   '@nike',
#   'fed',
#   'lie',
#   'antifa',
#   'organization',
#   'per',
#   'se',
#   'know',
#   'acronym',
#   'antifa',
#   'mean',
#   'fascism',
#   'know',
#   'corrupt',
#   'leader',
#   'like',
#   'hitler',
#   'mussolini',
#   'fascist',
#   'father',
#   'fought',
#   'ww',
#   'antifa',
#   'trump',
#   'nature',
#   'fascist'],
#  ['honestly', 'really', 'fuck', 'nike', 'much', 'one', 'fuck', 'brand'],
#  ['@anacabrera', 'nike', 'support', 'lawmaker'],
#  ['neon', 'nike', 'outfit', 'people'],
#  ['@wtpnews', '@sparkledocmad', 'bye', 'nike', 'suck', 'day', 'anyway'],
#  ['@foxlyfe',
#   '@againcheeky',
#   '@anacabrera',
#   '@donwinslow',
#   '@nike',
#   'poor',
#   'snowflake'],
#  ['@denisewu',
#   'fact',
#   'nike',
#   'would',
#   'supporting',
#   'politician',
#   'attempted',
#   'boycott',
#   'time',
#   'kind',
#   'surprising'],
#  ['#entertainmentcelebrity',
#   'check',
#   'notre',
#   'nike',
#   'dunk',
#   'high',
#   'blue',
#   'void',
#   'chicago-based',
#   'boutique',
#   'notre',
#   'nike',
#   'two',
#   'take',
#   'dunk',
#   'high',
#   'set',
#   'drop',
#   'official',
#   'image',
#   'light',
#   'orewood',
#   'brown',
#   'style',
#   'revealed',
#   'last',
#   'week'],
#  ['@nike',
#   '@goretexna',
#   'cruzrones',
#   'would',
#   'nice',
#   'addition',
#   'rainy',
#   'pnw',
#   'day',
#   'trying',
#   '#makesportadailyhabit',
#   '...',
#   'even',
#   'rain'],
#  ['@yungblackauteur', 'cj', 'said', 'personal', 'nike', 'trainer', 'thank'],
#  ['@anacabrera', 'wut', 'would', 'nike', 'supported', 'previously'],
#  ['success', 'nelly', 'nike', 'account'],
#  ['nike', 'definitely', 'need', 'catch', 'wake'],
#  ['@ack', '@anacabrera', 'another', 'win', 'nike', 'marketing', 'genius'],
#  ['@anacabrera',
#   'someday',
#   'people',
#   'going',
#   'realize',
#   'nike',
#   'different',
#   'people',
#   'early',
#   'th',
#   'century',
#   'used',
#   'slave',
#   'grow',
#   'cotton'],
#  ['first',
#   'one',
#   'sharing',
#   'twitter',
#   'like',
#   'let',
#   'know',
#   'want',
#   'write',
#   'thread',
#   '@glossier',
#   '@nike',
#   '@lululemon',
#   '@lego_group',
#   'brand',
#   'like',
#   'next'],
#  ['@nike',
#   '@nikestore',
#   'morning',
#   'vented',
#   'frustration',
#   'regarding',
#   'app',
#   'stock',
#   'reaction',
#   'tweet',
#   'immediately',
#   'dealt',
#   'faith',
#   'nike',
#   'restored',
#   'thank',
#   'taking',
#   'every',
#   'customer',
#   'seriously',
#   'safe']]

# %%
# before vectorizing, cast lists of words back into strings

df['final_docs'] = df['lemmatized'].apply(lambda x: " ".join(x))
pd.set_option('display.max_colwidth', -1)
final_docs = df['final_docs']
final_docs[3000:3020]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 5605    indeed
# 5606    everybody hate nike ...
# 5608    top seller week am ... volt purple use code nike extra
# 5610    ad restock nike air force wb wheat
# 5614    @tontolet follow follow back let's mutuals
# 5615    @elevated_online @raymondstone i've found nike run club terribly accurate always told running least second faster per km know
# 5616    @surgeryrunner saucony endorphin shift well padded around ankle super cushioned look like go mile good review also using new balance shorter easy run great review nike also released infinity react look good
# 5617    went back comment last night explained filoni also force female event nike reply well even know look bad
# 5619    restock nike air force wb wheat #ad
# 5622    nike update killshot og deep royal gray fog colorways #sneakers
# 5623    sale nike air force drip
# 5626    ran kilometre nike run club
# 5628    huge shoutout @snkrsforall lit pair nike dunk low coast first definitely come without
# 5629    @tdnconcepts @nike @nikeservice @nikesb @nikestore @nikenyc @nikelondon @nikecom_kr @nikedeveloper @nikela @nikerio thank tdn
# 5630    @james_athletics lot spent puma recently got neymar nike lamello ball nba fwise omar mcleod de grasse mahuchick mondo pinto warholm thats quite roster
# 5631    @igdirli_ @followkween follow follow back let's mutuals
# 5632    blame nike
# 5635    @aliabdaal nike running club best listening coach bennett fave way run
# 5637    @madewidthlove hello nice meet factory china specializing production vulcanized shoe work shoe sport shoe converse vance adidas nike timberland carter brand welcome consultation wechat crazyandy whatsapp
# 5640    @anthonymsg @mfarsi @nyknicks @thegarden @kith @nikebasketball @nike gm man let's win game
# Name: final_docs, dtype: object

# %% [markdown]
# # Part 3: NMF and LDA topic modeling

# %%
#create document term matrix with TFIDF

#import vectorizing tool (usee TFIDF)
from sklearn.feature_extraction.text import TfidfVectorizer
# set max_features to 2000 (specifies the number of most frequently occurring words for which we want to create feature vectors)
# set min_df to 5 (word must occur in at least 5 documents)
# set max_df to 0.85 (word must not occur in more than 85 percent of the documents) 

tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.85, ngram_range=(1, 2), stop_words='english')  
doc_term_matrix_1 = tfidfconverter.fit_transform(df['final_docs'].values.astype('U'))

# %%
#run NMF model 

#import NMF tool 
from sklearn.decomposition import NMF

nmf_model = NMF(n_components=6)
nmf_Z = nmf_model.fit_transform(doc_term_matrix_1)

# %%
# run LDA model

#import LDA tool 
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 6, max_iter=10, learning_method='online', learning_decay=.9)
lda_Z = lda_model.fit_transform(doc_term_matrix_1)

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model:")
print_topics(lda_model, tfidfconverter )
print("=" * 30)
 
print("NMF Model:")
print_topics(nmf_model, tfidfconverter )
print("=" * 30)
# Out:
# LDA Model:
# Topic 0:
# [('like', 697.0645948971771), ('got', 430.7047713824012), ('adidas', 425.0214159858603), ('like nike', 348.2705917838978), ('shoe', 330.5008387656179), ('store', 301.42170096487337), ('know', 286.78483715355554), ('blazer', 269.2888279476083), ('right', 261.2167214317633), ('people', 256.8246661676234)]
# Topic 1:
# [('jordan', 427.23437900640465), ('check', 404.8758103796641), ('added', 390.32706636251146), ('closet', 374.52353336889274), ('poshmarkapp shopmycloset', 370.0107336110526), ('run', 362.87972732961197), ('closet poshmark', 361.22471160861795), ('check added', 361.22469155153453), ('added closet', 361.22468682693886), ('poshmark', 307.0994312034846)]
# Topic 2:
# [('new', 459.4530627843483), ('shoe', 307.4884984178751), ('need', 307.48577075841627), ('love', 261.59525579742626), ('tech', 254.88088745996964), ('think', 248.6773571937578), ('thank', 234.2630743436685), ('want', 223.5648709242389), ('nike tech', 220.33751616867065), ('balance', 214.0145261232407)]
# Topic 3:
# [('good', 612.2305450542729), ('fashion', 562.5978134542506), ('item', 530.1819214279022), ('share', 525.3099030053529), ('loving', 505.035593129431), ('check', 500.0775779475922), ('style', 495.6584188995394), ('fashion style', 494.05489107514927), ('check item', 493.93919807279747), ('good share', 492.99094236480903)]
# Topic 4:
# [('air', 1053.2179240731346), ('nike air', 940.2441075783802), ('dunk', 781.9939777261654), ('max', 605.821340123259), ('air max', 587.0029172767345), ('low', 572.01629270648), ('nike dunk', 558.2909975750262), ('ad', 533.0333790063784), ('force', 481.34593457336837), ('white', 477.0954157788847)]
# Topic 5:
# [('look', 322.8050134837314), ('say', 261.58541212847354), ('fuck', 211.57613082903694), ('better', 189.65688704174943), ('supreme', 183.73516203856028), ('shirt', 181.9064957041882), ('available', 179.0719376927732), ('today', 167.06546614237547), ('work', 163.98409663864166), ('order', 163.22047024758072)]
# ==============================
# NMF Model:
# Topic 0:
# [('check item', 1.6304492852192476), ('item loving', 1.6297578827775756), ('poshmark fashion', 1.6297578827775756), ('loving poshmarkapp', 1.6297578827775756), ('share check', 1.6297578827775756), ('style shopmycloset', 1.6297578827775756), ('good share', 1.6297564646409375), ('fashion style', 1.6285874294269216), ('loving', 1.6282162264998779), ('share', 1.6143426146709796)]
# Topic 1:
# [('air', 3.2305325293340448), ('nike air', 2.9699469220334196), ('max', 1.893184874824135), ('air max', 1.8646219076262114), ('force', 1.1488356961582236), ('air force', 1.1370335841935788), ('ad', 0.8157935800736128), ('size', 0.579170434548071), ('shipping', 0.5441840041286751), ('free', 0.5355066223736513)]
# Topic 2:
# [('poshmarkapp shopmycloset', 1.619449203117012), ('added', 1.612347691702401), ('closet poshmark', 1.610216042320261), ('check added', 1.610216042320261), ('added closet', 1.610216042320261), ('closet', 1.6065937463550213), ('poshmark nike', 1.3567999394530141), ('poshmarkapp', 1.3153719791800582), ('poshmark', 1.3144893444585755), ('shopmycloset', 1.3105287928900577)]
# Topic 3:
# [('dunk', 2.8524035821197526), ('nike dunk', 2.178887644521962), ('low', 1.7989598488051661), ('dunk low', 1.7401866273260973), ('sb', 0.7723767705830515), ('nike sb', 0.6748012013388133), ('release', 0.6587923359464483), ('sb dunk', 0.6131332806601232), ('high', 0.5594092042652851), ('dunk high', 0.5404716896009394)]
# Topic 4:
# [('like', 3.796711395762192), ('like nike', 2.5842362209735543), ('look', 0.4127839321693847), ('look like', 0.34538310770366865), ('say', 0.2367327659607724), ('got', 0.21161546807287354), ('make', 0.2021962864357936), ('nike like', 0.19161670359539412), ('shit', 0.18961392776571875), ('know', 0.18114187916481228)]
# Topic 5:
# [('shoe', 2.5487321552579636), ('new', 1.4230594069783673), ('nike shoe', 1.3814418249002047), ('balance', 0.693413176821042), ('new balance', 0.6848078362558271), ('nike new', 0.6393525339277522), ('adidas', 0.5983741695221695), ('running', 0.36547878640577), ('need', 0.34200337750588633), ('new nike', 0.3305892931609231)]
# ==============================

# %%
# make results of LDA2 model a column in dataframe

topic_values = lda_model.transform(doc_term_matrix_1)
df['LDA1_topic'] = topic_values.argmax(axis=1)

# %%
df[df.LDA1_topic == 5][:20]
# Out:
#                       id          parsed_created_at user_screen_name  \
# 6    1349427641389084672  2021-01-13 18:46:35+00:00  jojobeans29
# 32   1349427289952550916  2021-01-13 18:45:11+00:00  Gulian74
# 35   1349427272810459136  2021-01-13 18:45:07+00:00  GQMagazine
# 49   1349427097098285056  2021-01-13 18:44:25+00:00  relsquared
# 55   1349427015586369537  2021-01-13 18:44:06+00:00  more_sneakers
# 63   1349426968559710208  2021-01-13 18:43:55+00:00  SoleCollector
# 84   1349426731413889024  2021-01-13 18:42:58+00:00  williamstoutjr2
# 88   1349426667836612608  2021-01-13 18:42:43+00:00  mjostew
# 131  1349426166772486147  2021-01-13 18:40:43+00:00  outofmySHEL
# 156  1349425802035789827  2021-01-13 18:39:16+00:00  Alessaaandro99
# 160  1349425762319872005  2021-01-13 18:39:07+00:00  Sir_Nike
# 161  1349425758448574465  2021-01-13 18:39:06+00:00  wtpnews76
# 162  1349425754195562496  2021-01-13 18:39:05+00:00  the_new_kid_04
# 163  1349425739276419077  2021-01-13 18:39:02+00:00  JohnApocalypse
# 168  1349425675191656456  2021-01-13 18:38:46+00:00  SweetPetiteTori
# 169  1349425644917018624  2021-01-13 18:38:39+00:00  CiiaqapLFraser
# 181  1349425565233778695  2021-01-13 18:38:20+00:00  eme_amah
# 184  1349425508799434755  2021-01-13 18:38:07+00:00  CourtsofOpinion
# 185  1349425506207191040  2021-01-13 18:38:06+00:00  orourkerules
# 206  1349425324254257152  2021-01-13 18:37:23+00:00  AscanBLN
#
#                                                                                                                                                                                                                                             text  \
# 6    Honestly I really do fuck with Nike as much as one can fuck with a brand.
# 32   @Nike gotta disregard the results on the SNKRS app and rerelease the @KingJames Hardwood Classic 7s
# 35   Snakeskin Supreme Nikes—need we say more? https://t.co/p72omuZnQ6 https://t.co/BqscQomEcD
# 49   Nike just produces such high quality.\nJustifies my purchases errrytine.
# 55   AD : Nike Air Force 1 'Rayguns'\nLATE DROP via Asphaltgold\n=&gt;https://t.co/2rBiv831gg\n=&gt;https://t.co/2rBiv831gg https://t.co/GFVOMPQ4TZ
# 63   Your best look yet\n\nSEE MORE: https://t.co/LpG28zkZIs
# 84   @KingSye30886074 @AnnCoulter Nike’s not good at supporting anyone. Just ask Zion Williamson. https://t.co/gH9amGx8hE
# 88   nike said just don’t ♥️ https://t.co/27zWp44ntr
# 131  Nike shouldn’t be supporting lawmakers. https://t.co/44WXImNyLf
# 156  @CFC_Cal Auba posted this on his main insta at the Nike event in February 👏🏽 https://t.co/BgCnxpi5Oj
# 160  @Ta_The_Godson I honestly have been buying shoes to use for trade. I just can’t deal with these insane prices that come with getting a size 9
# 161  BREAKING: NIKE WILL WITHHOLD ALL SUPPORT TO LAWMAKERS THAT OPPOSED THE ELECTION CERTIFICATION
# 162  The Nike app strikes again, I gotta stop going on there when I’m bored 🙃😂
# 163  @AnaCabrera Why should anyone care what Nike has to say?
# 168  Literally what I’m getting today &amp; @Nike y’all are trippin on your prices for this shit bruh https://t.co/vKFlBuncRt
# 169  What was #NIKE doing funding the rise of Fascism in the first place? https://t.co/VcIAFh3yUJ
# 181  by that photo nike u i s?? ahead? simply space d?? https://t.co/kTPL5vrH4V
# 184  @ryaninsix @NBA @BR_NBA @espn @SBNation @LVAces @Nike @nikebasketball @HoHighlights These are fresh 💯
# 185  @AnaCabrera @donwinslow Hey Nike, mark down Utah reps @RepBurgessOwens @RepChrisStewart They are a disgrace to our state and both objected to results of an election they won. They should resign if they really believe in election fraud.
# 206  NIKE posters are looking insane 🔥 @z0kii https://t.co/9PQDjGihIP
#
#     tweet_type hashtags  favorite_count possibly_sensitive  retweet_count  \
# 6    original   NaN      0               NaN                0
# 32   original   NaN      0               NaN                0
# 35   original   NaN      2               False              0
# 49   original   NaN      0               NaN                0
# 55   original   NaN      3               False              0
# 63   original   NaN      10              False              1
# 84   reply      NaN      0               False              0
# 88   quote      NaN      0               False              0
# 131  quote      NaN      0               False              0
# 156  reply      NaN      1               False              0
# 160  reply      NaN      0               NaN                0
# 161  original   NaN      11              NaN                11
# 162  original   NaN      0               NaN                0
# 163  reply      NaN      0               NaN                0
# 168  quote      NaN      1               False              0
# 169  quote      NIKE     0               False              0
# 181  original   NaN      0               False              0
# 184  reply      NaN      0               NaN                0
# 185  reply      NaN      0               NaN                0
# 206  quote      NaN      2               False              1
#
#                  user_id  \
# 6    3404373975
# 32   52489336
# 35   21701757
# 49   2314538184
# 55   1411447658
# 63   19382500
# 84   1223275293219213312
# 88   294844976
# 131  119654973
# 156  858653221
# 160  470830926
# 161  1342988534123212802
# 162  364034967
# 163  305875716
# 168  846155317943697408
# 169  1038301598
# 181  1145748611399114754
# 184  1331369134811205632
# 185  146983030
# 206  592756136
#
#                                                                                                                                                                           processed_text  \
# 6    [honestly, really, fuck, nike, much, one, fuck, brand]
# 32   [@nike, gotta, disregard, results, snkrs, app, rerelease, @kingjames, hardwood, classic]
# 35   [snakeskin, supreme, nikes, need, say]
# 49   [nike, produces, high, quality, justifies, purchases, errrytine]
# 55   [ad, nike, air, force, rayguns, late, drop, via, asphaltgold]
# 63   [best, look, yet, see]
# 84   [@kingsye, @anncoulter, nike, good, supporting, anyone, ask, zion, williamson]
# 88   [nike, said]
# 131  [nike, supporting, lawmakers]
# 156  [@cfc_cal, auba, posted, main, insta, nike, event, february]
# 160  [@ta_the_godson, honestly, buying, shoes, use, trade, deal, insane, prices, come, getting, size]
# 161  [breaking, nike, withhold, support, lawmakers, opposed, election, certification]
# 162  [nike, app, strikes, gotta, stop, going, bored]
# 163  [@anacabrera, anyone, care, nike, say]
# 168  [literally, getting, today, @nike, trippin, prices, shit, bruh]
# 169  [#nike, funding, rise, fascism, first, place]
# 181  [photo, nike, ahead, simply, space]
# 184  [@ryaninsix, @nba, @br_nba, @espn, @sbnation, @lvaces, @nike, @nikebasketball, @hohighlights, fresh]
# 185  [@anacabrera, @donwinslow, hey, nike, mark, utah, reps, @repburgessowens, @repchrisstewart, disgrace, state, objected, results, election, resign, really, believe, election, fraud]
# 206  [nike, posters, looking, insane, @zkii]
#
#                                                                                                                                                                                                                                                                                                      pos_tagged  \
# 6    [(honestly, RB), (really, RB), (fuck, VB), (nike, RB), (much, JJ), (one, CD), (fuck, NN), (brand, NN)]
# 32   [(@nike, IN), (gotta, NNS), (disregard, JJ), (results, NNS), (snkrs, JJ), (app, JJ), (rerelease, NN), (@kingjames, NNS), (hardwood, VBD), (classic, JJ)]
# 35   [(snakeskin, JJ), (supreme, NN), (nikes, NNS), (need, VBP), (say, VBP)]
# 49   [(nike, JJ), (produces, VBZ), (high, JJ), (quality, NN), (justifies, NNS), (purchases, NNS), (errrytine, VBP)]
# 55   [(ad, NN), (nike, IN), (air, NN), (force, NN), (rayguns, NN), (late, JJ), (drop, NN), (via, IN), (asphaltgold, NN)]
# 63   [(best, JJS), (look, NN), (yet, RB), (see, VB)]
# 84   [(@kingsye, JJ), (@anncoulter, NN), (nike, RB), (good, JJ), (supporting, VBG), (anyone, NN), (ask, JJ), (zion, NN), (williamson, NN)]
# 88   [(nike, NN), (said, VBD)]
# 131  [(nike, IN), (supporting, VBG), (lawmakers, NNS)]
# 156  [(@cfc_cal, JJ), (auba, NN), (posted, VBD), (main, JJ), (insta, NN), (nike, JJ), (event, NN), (february, NN)]
# 160  [(@ta_the_godson, NN), (honestly, RB), (buying, VBG), (shoes, NNS), (use, RB), (trade, VBP), (deal, NN), (insane, NN), (prices, NNS), (come, VBP), (getting, VBG), (size, NN)]
# 161  [(breaking, VBG), (nike, IN), (withhold, JJ), (support, NN), (lawmakers, NNS), (opposed, VBD), (election, NN), (certification, NN)]
# 162  [(nike, IN), (app, JJ), (strikes, NNS), (gotta, VBP), (stop, VB), (going, VBG), (bored, JJ)]
# 163  [(@anacabrera, NN), (anyone, NN), (care, NN), (nike, IN), (say, VBP)]
# 168  [(literally, RB), (getting, VBG), (today, NN), (@nike, IN), (trippin, NN), (prices, NNS), (shit, VBD), (bruh, NN)]
# 169  [(#nike, IN), (funding, VBG), (rise, NN), (fascism, NN), (first, JJ), (place, NN)]
# 181  [(photo, NN), (nike, IN), (ahead, RB), (simply, RB), (space, NN)]
# 184  [(@ryaninsix, JJ), (@nba, NNP), (@br_nba, NNP), (@espn, NNP), (@sbnation, NNP), (@lvaces, NNS), (@nike, VBP), (@nikebasketball, JJ), (@hohighlights, NNS), (fresh, JJ)]
# 185  [(@anacabrera, NN), (@donwinslow, NN), (hey, NN), (nike, IN), (mark, NN), (utah, JJ), (reps, NNS), (@repburgessowens, VBZ), (@repchrisstewart, JJ), (disgrace, NN), (state, NN), (objected, VBD), (results, NNS), (election, NN), (resign, VBP), (really, RB), (believe, VB), (election, NN), (fraud, NN)]
# 206  [(nike, IN), (posters, NNS), (looking, VBG), (insane, NN), (@zkii, NN)]
#
#                                                                                                                                                                             lemmatized  \
# 6    [honestly, really, fuck, nike, much, one, fuck, brand]
# 32   [@nike, gotta, disregard, result, snkrs, app, rerelease, @kingjames, hardwood, classic]
# 35   [snakeskin, supreme, nike, need, say]
# 49   [nike, produce, high, quality, justifies, purchase, errrytine]
# 55   [ad, nike, air, force, rayguns, late, drop, via, asphaltgold]
# 63   [best, look, yet, see]
# 84   [@kingsye, @anncoulter, nike, good, supporting, anyone, ask, zion, williamson]
# 88   [nike, said]
# 131  [nike, supporting, lawmaker]
# 156  [@cfc_cal, auba, posted, main, insta, nike, event, february]
# 160  [@ta_the_godson, honestly, buying, shoe, use, trade, deal, insane, price, come, getting, size]
# 161  [breaking, nike, withhold, support, lawmaker, opposed, election, certification]
# 162  [nike, app, strike, gotta, stop, going, bored]
# 163  [@anacabrera, anyone, care, nike, say]
# 168  [literally, getting, today, @nike, trippin, price, shit, bruh]
# 169  [#nike, funding, rise, fascism, first, place]
# 181  [photo, nike, ahead, simply, space]
# 184  [@ryaninsix, @nba, @br_nba, @espn, @sbnation, @lvaces, @nike, @nikebasketball, @hohighlights, fresh]
# 185  [@anacabrera, @donwinslow, hey, nike, mark, utah, rep, @repburgessowens, @repchrisstewart, disgrace, state, objected, result, election, resign, really, believe, election, fraud]
# 206  [nike, poster, looking, insane, @zkii]
#
#                                                                                                                                                         final_docs  \
# 6    honestly really fuck nike much one fuck brand
# 32   @nike gotta disregard result snkrs app rerelease @kingjames hardwood classic
# 35   snakeskin supreme nike need say
# 49   nike produce high quality justifies purchase errrytine
# 55   ad nike air force rayguns late drop via asphaltgold
# 63   best look yet see
# 84   @kingsye @anncoulter nike good supporting anyone ask zion williamson
# 88   nike said
# 131  nike supporting lawmaker
# 156  @cfc_cal auba posted main insta nike event february
# 160  @ta_the_godson honestly buying shoe use trade deal insane price come getting size
# 161  breaking nike withhold support lawmaker opposed election certification
# 162  nike app strike gotta stop going bored
# 163  @anacabrera anyone care nike say
# 168  literally getting today @nike trippin price shit bruh
# 169  #nike funding rise fascism first place
# 181  photo nike ahead simply space
# 184  @ryaninsix @nba @br_nba @espn @sbnation @lvaces @nike @nikebasketball @hohighlights fresh
# 185  @anacabrera @donwinslow hey nike mark utah rep @repburgessowens @repchrisstewart disgrace state objected result election resign really believe election fraud
# 206  nike poster looking insane @zkii
#
#      LDA1_topic
# 6    5
# 32   5
# 35   5
# 49   5
# 55   5
# 63   5
# 84   5
# 88   5
# 131  5
# 156  5
# 160  5
# 161  5
# 162  5
# 163  5
# 168  5
# 169  5
# 181  5
# 184  5
# 185  5
# 206  5

# %%
# cross-validation to find best parameters for LDA model

#import cross-validation tool
from sklearn.model_selection import GridSearchCV

# define search parameters
search_params = {'n_components': [5, 8, 10, 12], 'learning_decay': [.5, .7, .9]}

# initialize model for cross-validation
lda = LatentDirichletAllocation()

# initialize grid search class 
model = GridSearchCV(lda, param_grid=search_params)

# run grid search 
model.fit(doc_term_matrix_1)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 8, 10, 12]})

# %%
# what is best model? 
best_lda_model = model.best_estimator_

# print parameters for best model
print("Parameters for best model: ", model.best_params_)

# print log likelihood score
print("Log likelihood score of best model: ", model.best_score_)

# print perplexity score
# Out:
# Parameters for best model:  {'learning_decay': 0.9, 'n_components': 5}
# Log likelihood score of best model:  -227422.72278921158
