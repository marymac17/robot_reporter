# %% [markdown]
# # Part 1: Data cleaning

# %%
#import initial libraries

import pandas as pd
import numpy as np

# %%
#import data 

df = pd.read_csv('data/pakistan.csv')

# %%
# look at basic info about data

df.info()
# this data set consists of 20286 Tweets
# Twarc search for keywords "Pakistan" AND "power" after major nationwide power outage was reported
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20286 entries, 0 to 20285
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            20286 non-null  int64
#  1   tweet_url                     20286 non-null  object
#  2   created_at                    20286 non-null  object
#  3   parsed_created_at             20286 non-null  object
#  4   user_screen_name              20286 non-null  object
#  5   text                          20286 non-null  object
#  6   tweet_type                    20286 non-null  object
#  7   coordinates                   0 non-null      float64
#  8   hashtags                      8270 non-null   object
#  9   media                         1989 non-null   object
#  10  urls                          3189 non-null   object
#  11  favorite_count                20286 non-null  int64
#  12  in_reply_to_screen_name       1492 non-null   object
#  13  in_reply_to_status_id         1431 non-null   float64
#  14  in_reply_to_user_id           1492 non-null   float64
#  15  lang                          20286 non-null  object
#  16  place                         121 non-null    object
#  17  possibly_sensitive            4461 non-null   object
#  18  retweet_count                 20286 non-null  int64
#  19  retweet_or_quote_id           15690 non-null  float64
#  20  retweet_or_quote_screen_name  15690 non-null  object
#  21  retweet_or_quote_user_id      15690 non-null  float64
#  22  source                        20276 non-null  object
#  23  user_id                       20286 non-null  int64
#  24  user_created_at               20286 non-null  object
#  25  user_default_profile_image    20286 non-null  bool
#  26  user_description              16887 non-null  object
#  27  user_favourites_count         20286 non-null  int64
#  28  user_followers_count          20286 non-null  int64
#  29  user_friends_count            20286 non-null  int64
#  30  user_listed_count             20286 non-null  int64
#  31  user_location                 13431 non-null  object
#  32  user_name                     20286 non-null  object
#  33  user_statuses_count           20286 non-null  int64
#  34  user_time_zone                0 non-null      float64
#  35  user_urls                     4497 non-null   object
#  36  user_verified                 20286 non-null  bool
# dtypes: bool(2), float64(6), int64(9), object(20)
# memory usage: 5.5+ MB

# %%
# count number of languages in data set

count_lang = df['lang'].unique()
print(len(count_lang), count_lang)
# Out:
# 31 ['en' 'ja' 'und' 'hi' 'de' 'ta' 'in' 'mr' 'gu' 'kn' 'da' 'es' 'ur' 'nl'
#  'or' 'tl' 'et' 'ht' 'pt' 'pl' 'tr' 'vi' 'eu' 'it' 'sv' 'no' 'fi' 'fr'
#  'ca' 'ro' 'pa']

# %%
# tweets are in 31 different languages

# I'll be working only with Tweets in English
# drop tweets in all other languages
# now working with 19459 Tweets 

df = df[df.lang == 'en']
df.shape
# Out:
# (19459, 37)

# %%
# check start time & date of data

df.iloc[0]

# first Tweet Sun Jan 10 03:32:31
# Out:
# id                                                            1348110445333209091
# tweet_url                       https://twitter.com/alienguru02/status/1348110...
# created_at                                         Sun Jan 10 03:32:31 +0000 2021
# parsed_created_at                                       2021-01-10 03:32:31+00:00
# user_screen_name                                                      alienguru02
# text                            Power blackout reported in multiple cities of ...
# tweet_type                                                                retweet
# coordinates                                                                   NaN
# hashtags                                                                      NaN
# media                                                                         NaN
# urls                                                                          NaN
# favorite_count                                                               5187
# in_reply_to_screen_name                                                       NaN
# in_reply_to_status_id                                                         NaN
# in_reply_to_user_id                                                           NaN
# lang                                                                           en
# place                                                                         NaN
# possibly_sensitive                                                            NaN
# retweet_count                                                                 486
# retweet_or_quote_id                                                   1.34799e+18
# retweet_or_quote_screen_name                                                  ANI
# retweet_or_quote_user_id                                              3.55989e+08
# source                          <a href="http://twitter.com/download/android" ...
# user_id                                                       1165175943968612354
# user_created_at                                    Sat Aug 24 08:16:19 +0000 2019
# user_default_profile_image                                                  False
# user_description                           शायर / लेखक / वैज्ञानिक \nJay Hind 🇮🇳🙏
# user_favourites_count                                                       75633
# user_followers_count                                                          283
# user_friends_count                                                           2319
# user_listed_count                                                               0
# user_location                                                                 NaN
# user_name                                                               I'm DeEp❤
# user_statuses_count                                                         16867
# user_time_zone                                                                NaN
# user_urls                                                                     NaN
# user_verified                                                               False
# Name: 0, dtype: object

# %%
# check end time & date of data 

df.iloc[-1]

# Sat Jan 02 12:56:37
# Out:
# id                                                            1345353303115395076
# tweet_url                       https://twitter.com/byzaa_g/status/13453533031...
# created_at                                         Sat Jan 02 12:56:37 +0000 2021
# parsed_created_at                                       2021-01-02 12:56:37+00:00
# user_screen_name                                                          byzaa_g
# text                            Bilateral trade between Pakistan&amp;Sri Lanka...
# tweet_type                                                                retweet
# coordinates                                                                   NaN
# hashtags                        SriLanka Pakistan PakArmy Khilafah StopMuslimC...
# media                                                                         NaN
# urls                                                                          NaN
# favorite_count                                                                 16
# in_reply_to_screen_name                                                       NaN
# in_reply_to_status_id                                                         NaN
# in_reply_to_user_id                                                           NaN
# lang                                                                           en
# place                                                                         NaN
# possibly_sensitive                                                            NaN
# retweet_count                                                                  21
# retweet_or_quote_id                                                   1.34535e+18
# retweet_or_quote_screen_name                                      WomenForKhilafa
# retweet_or_quote_user_id                                              4.89763e+08
# source                          <a href="http://twitter.com/download/android" ...
# user_id                                                       1111552431068991493
# user_created_at                                    Fri Mar 29 08:55:25 +0000 2019
# user_default_profile_image                                                  False
# user_description                                                              NaN
# user_favourites_count                                                        5610
# user_followers_count                                                           19
# user_friends_count                                                             31
# user_listed_count                                                               0
# user_location                                                                 NaN
# user_name                                                                  Ahsenn
# user_statuses_count                                                          5654
# user_time_zone                                                                NaN
# user_urls                                                                     NaN
# user_verified                                                               False
# Name: 20285, dtype: object

# %% [markdown]
# # Part 2: Text processing for NLP

# %%
# create variable for "text" column 

text = df['text']

# %%
# tokenize, remove stopwords, remove urls, lowercase, remove punctuation, remove numbers
# import necessary libraries: ntlk etc.

import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 

stop = stopwords.words('english')

punc = list(set(string.punctuation))

def tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_url(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r'', text)

def process_text(text):
    text = remove_url(text)
    text = tokenizer(text)
    text = [word.lower() for word in text]
    text = [re.sub('[0-9]+', '', word) for word in text]
    text = [word for word in text if word not in punc]
    text = [word for word in text if word not in stop]
    text = [each for each in text if len(each) > 1]
    text = [word for word in text if ' ' not in word]
     
    return text

# %%
# apply text processing functions to text

df['processed_text'] = df['text'].apply(process_text)

# %%
# look at some of processed text

pd.set_option('display.max_colwidth', -1)
df['processed_text'][:20]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0     [power, blackout, reported, multiple, cities, pakistan, pakistan, media]
# 1     [true, sad, state, affairs, #pakistan, nationwide, power, cut, pak, fears, either, coup, air, strike, claim, killed, crows, damaged, trees, heart, hearts, know, india, sent, strong, message, balakot, airstrikes]
# 2     [power, blackout, reported, multiple, cities, pakistan, pakistan, media]
# 3     [major, power, grid, failure, #pakistan, karachi, islamabad, lahore, total, blackout]
# 4     [@jovanhpulitzer, election, switching, usa, ->, leaonardo, vatican, ->, pakistan, ->, china, ->, frankfurt-usa, hours, ago, pakistan, complete, power, outage, total, grid, failure, vatican, complete, power, failure, red]
# 5     [pakistan, experiences, massive, blackout, following, breakdown, national, power, grid]
# 6     [@teamlarcho, pakistan, national, power, outage, ):]
# 7     [pakistan, nationwide, power, grid, shutdown, right, i'll, video, min, btw, that's, million, people, without, power, population, think, can't, happen]
# 8     [confirmed, #pakistan, internet, connectivity, collapses, amid, widespread, power, outage, nation-scale, impact, real-time, network, data, show, connectivity, ordinary, levels, users, struggle, get, online, incident, ongoing, #blackoutpakistan]
# 9     [power, supply, goes, pakistan, abdul, salma, blackout]
# 10    [weird, ..., vatican, pakistan]
# 11    [@rmichanczyk, @jovanhpulitzer, election, switching, usa, ->, leaonardo, vatican, ->, pakistan, ->, china, ->, frankfurt-usa, hours, ago, pakistan, complete, power, outage, total, grid, failure, vatican, complete, power, failure, red]
# 12    [much, pakistan, plunged, darkness, widespread, power, failure]
# 13    [blackout, major, cities, pakistan, power, failure, army, rule]
# 14    [pakistan, hit, massive, power, blackout, officials, say, much, country, including, major, cities, plunged, darkness]
# 15    [@abpnews, historic, power, blackout, strike, pakistan, modi, government]
# 16    [#pakistan, power, cut, plunges, country, darkness, rising, sun, would, bring, relief]
# 17    [#powerblackout, #pakistan, #cities, #darkness, #dy, massive, power, blackout, pakistan, several, cities, plunged, darkness]
# 18    [@roncoleman, @potus, prepare, coming, pakistan, large, country, million, people, entire, country, power, frequency, drop, water, food, things, barter]
# 19    [power, blackout, reported, multiple, cities, pakistan, pakistan, media]
# Name: processed_text, dtype: object

# %%
# part-of-speech tagging 

ready_for_pos = df['processed_text']

def pos_tagging(text):
    pos_tag = [pos_tag(word) for word in ready_for_pos]

df['pos_tagged'] = df.processed_text.apply(lambda x: pos_tag(x))

# %%
# lemmatizing

pos_tagged = df['pos_tagged']

wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
# look at lemmatized text

df['lemmatized'] = lemmatized
lemmatized[:20]
# Out:
# [['power',
#   'blackout',
#   'reported',
#   'multiple',
#   'city',
#   'pakistan',
#   'pakistan',
#   'medium'],
#  ['true',
#   'sad',
#   'state',
#   'affair',
#   '#pakistan',
#   'nationwide',
#   'power',
#   'cut',
#   'pak',
#   'fear',
#   'either',
#   'coup',
#   'air',
#   'strike',
#   'claim',
#   'killed',
#   'crow',
#   'damaged',
#   'tree',
#   'heart',
#   'heart',
#   'know',
#   'india',
#   'sent',
#   'strong',
#   'message',
#   'balakot',
#   'airstrikes'],
#  ['power',
#   'blackout',
#   'reported',
#   'multiple',
#   'city',
#   'pakistan',
#   'pakistan',
#   'medium'],
#  ['major',
#   'power',
#   'grid',
#   'failure',
#   '#pakistan',
#   'karachi',
#   'islamabad',
#   'lahore',
#   'total',
#   'blackout'],
#  ['@jovanhpulitzer',
#   'election',
#   'switching',
#   'usa',
#   '->',
#   'leaonardo',
#   'vatican',
#   '->',
#   'pakistan',
#   '->',
#   'china',
#   '->',
#   'frankfurt-usa',
#   'hour',
#   'ago',
#   'pakistan',
#   'complete',
#   'power',
#   'outage',
#   'total',
#   'grid',
#   'failure',
#   'vatican',
#   'complete',
#   'power',
#   'failure',
#   'red'],
#  ['pakistan',
#   'experience',
#   'massive',
#   'blackout',
#   'following',
#   'breakdown',
#   'national',
#   'power',
#   'grid'],
#  ['@teamlarcho', 'pakistan', 'national', 'power', 'outage', '):'],
#  ['pakistan',
#   'nationwide',
#   'power',
#   'grid',
#   'shutdown',
#   'right',
#   "i'll",
#   'video',
#   'min',
#   'btw',
#   "that's",
#   'million',
#   'people',
#   'without',
#   'power',
#   'population',
#   'think',
#   "can't",
#   'happen'],
#  ['confirmed',
#   '#pakistan',
#   'internet',
#   'connectivity',
#   'collapse',
#   'amid',
#   'widespread',
#   'power',
#   'outage',
#   'nation-scale',
#   'impact',
#   'real-time',
#   'network',
#   'data',
#   'show',
#   'connectivity',
#   'ordinary',
#   'level',
#   'user',
#   'struggle',
#   'get',
#   'online',
#   'incident',
#   'ongoing',
#   '#blackoutpakistan'],
#  ['power', 'supply', 'go', 'pakistan', 'abdul', 'salma', 'blackout'],
#  ['weird', '...', 'vatican', 'pakistan'],
#  ['@rmichanczyk',
#   '@jovanhpulitzer',
#   'election',
#   'switching',
#   'usa',
#   '->',
#   'leaonardo',
#   'vatican',
#   '->',
#   'pakistan',
#   '->',
#   'china',
#   '->',
#   'frankfurt-usa',
#   'hour',
#   'ago',
#   'pakistan',
#   'complete',
#   'power',
#   'outage',
#   'total',
#   'grid',
#   'failure',
#   'vatican',
#   'complete',
#   'power',
#   'failure',
#   'red'],
#  ['much', 'pakistan', 'plunged', 'darkness', 'widespread', 'power', 'failure'],
#  ['blackout', 'major', 'city', 'pakistan', 'power', 'failure', 'army', 'rule'],
#  ['pakistan',
#   'hit',
#   'massive',
#   'power',
#   'blackout',
#   'official',
#   'say',
#   'much',
#   'country',
#   'including',
#   'major',
#   'city',
#   'plunged',
#   'darkness'],
#  ['@abpnews',
#   'historic',
#   'power',
#   'blackout',
#   'strike',
#   'pakistan',
#   'modi',
#   'government'],
#  ['#pakistan',
#   'power',
#   'cut',
#   'plunge',
#   'country',
#   'darkness',
#   'rising',
#   'sun',
#   'would',
#   'bring',
#   'relief'],
#  ['#powerblackout',
#   '#pakistan',
#   '#cities',
#   '#darkness',
#   '#dy',
#   'massive',
#   'power',
#   'blackout',
#   'pakistan',
#   'several',
#   'city',
#   'plunged',
#   'darkness'],
#  ['@roncoleman',
#   '@potus',
#   'prepare',
#   'coming',
#   'pakistan',
#   'large',
#   'country',
#   'million',
#   'people',
#   'entire',
#   'country',
#   'power',
#   'frequency',
#   'drop',
#   'water',
#   'food',
#   'thing',
#   'barter'],
#  ['power',
#   'blackout',
#   'reported',
#   'multiple',
#   'city',
#   'pakistan',
#   'pakistan',
#   'medium']]

# %%
# before vectorizing, cast lists of words back into strings

df['final_docs'] = df['lemmatized'].apply(lambda x: " ".join(x))
pd.set_option('display.max_colwidth', -1)
final_docs = df['final_docs']
final_docs[3000:3020]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 3211    #update massive power blackout plunged entire pakistan darkness report dawn news
# 3212    large area pakistan plunged darkness first time happened country's power infrastructure fragile past separatist attack blamed outage appear case time stay safe
# 3213    pakistan blackout leaf million without power ... nuclear power
# 3214    power shut major city pakistan mean whole pakistan power moment happened rarely anyone update reason
# 3215    pakistan experience massive blackout following breakdown national power grid
# 3216    massive power outage plunge pakistan darkness
# 3217    pakistan experience massive blackout following breakdown national power grid
# 3218    blackout pakistan bit suspicious entire country lose power effect everything ... communication business hospital government #pakistanblackout
# 3219    massive power outage plunge pakistan darkness
# 3220    pakistan experience massive blackout following breakdown national power grid
# 3221    massive power outage plunge pakistan darkness
# 3222    #electricity expected restored across pakistan karachi islamabad expected electricity back within next hour due power plant #blackout #poweroutage
# 3223    national power control center confirmed #electricity #blackout whole pakistan due drop frequency team trying find reason #poweroutage
# 3224    massive power outage plunge pakistan darkness
# 3225    power blackout reported multiple city pakistan pakistan medium
# 3226    national power grid breakdown plunge pakistan darkness
# 3227    national power grid breakdown plunge pakistan darkness
# 3228    power breakdown exists pray well meri zindagi ap bagair hai itni dark jitna wqt pura pakistan
# 3229    #دہشتگردی_کےخلاف_متحدپاکستان power earth undo pakistan #ہماری_آستین_میں_سانپ_ہیں
# 3230    pakistan experience massive blackout following breakdown national power grid
# Name: final_docs, dtype: object

# %%
#create document term matrix with TFIDF

#import vectorizing tool (usee TFIDF)
from sklearn.feature_extraction.text import TfidfVectorizer
# set max_features to 2000 (specifies the number of most frequently occurring words for which we want to create feature vectors)
# set min_df to 5 (word must occur in at least 5 documents)
# set max_df to 0.85 (word must not occur in more than 85 percent of the documents) 

tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.85, ngram_range=(1, 2), stop_words='english')  
doc_term_matrix_1 = tfidfconverter.fit_transform(df['final_docs'].values.astype('U'))

# %% [markdown]
# # Part 3: run NMF and LDA models, for topic modeling

# %%
#run NMF model 

#import NMF tool 
from sklearn.decomposition import NMF

nmf_model = NMF(n_components=6)
nmf_Z = nmf_model.fit_transform(doc_term_matrix_1)

# %%
# run LDA model

#import LDA tool 
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 6, max_iter=10, learning_method='online', learning_decay=.9)
lda_Z = lda_model.fit_transform(doc_term_matrix_1)

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model:")
print_topics(lda_model, tfidfconverter )
print("=" * 20)
 
print("NMF Model:")
print_topics(nmf_model, tfidfconverter )
print("=" * 20)
# Out:
# LDA Model:
# Topic 0:
# [('hit', 137.75718834657042), ('million', 120.59797436777058), ('pakistan hit', 113.34606698990156), ('blackout', 89.56008590234167), ('_ह', 84.09149686138308), ('million power', 82.45945143669144), ('nationwide', 75.29605261909242), ('daughter', 73.16867848798611), ('power blackout', 73.06189973487683), ('nationwide blackout', 67.49008623873388)]
# Topic 1:
# [('outage', 131.69533837851947), ('earth', 126.64646961163753), ('power earth', 123.23292818391491), ('power outage', 117.54423819187159), ('outage pakistan', 117.07060156811124), ('undo', 114.24973784759433), ('undo pakistan', 112.35378033326123), ('muslim', 103.78684805690335), ('unitedpakistanforummah', 102.604011583609), ('day', 96.57214801178466)]
# Topic 2:
# [('breakdown', 379.8711642146731), ('power grid', 328.37392279563676), ('grid', 316.1995903769569), ('bitcoin', 308.1952308865371), ('country', 303.59305876317444), ('practically', 301.58532234911866), ('darkness', 259.8310877076762), ('grid breakdown', 256.5430494280992), ('plunge', 255.7749528059084), ('breakdown pakistan', 243.59829497363432)]
# Topic 3:
# [('blackout', 199.13043258296247), ('khan', 179.26983645781627), ('imran', 170.7377166595757), ('major', 166.44830727938273), ('imran khan', 142.32058201217805), ('karachi', 131.16696886225526), ('islamabad', 124.3914121251783), ('power pakistan', 122.97854547398563), ('major power', 121.12694005319894), ('electricity', 114.4844781076508)]
# Topic 4:
# [('power supply', 290.1353628885604), ('supply', 288.08002429323665), ('hospital', 286.42832721446723), ('currently', 281.1101181653396), ('hope', 276.28296617712715), ('pray', 275.80847374091746), ('ventilator', 275.61841989084974), ('hospital pakistan', 272.9281319994345), ('hope hospital', 271.2461238247496), ('adequate power', 268.4366686681451)]
# Topic 5:
# [('entire pakistan', 290.1731420587789), ('pakistan pakistan', 281.194058398361), ('power blackout', 247.15524145466568), ('entire', 243.10058574037885), ('air', 207.0202284407779), ('force', 199.58038245693476), ('air force', 198.39491713397587), ('blackout', 197.21364103772672), ('alert', 192.4812716544812), ('red', 191.29658219744573)]
# ====================
# NMF Model:
# Topic 0:
# [('hospital', 1.3586830726017678), ('hope hospital', 1.3542323146504625), ('hospital pakistan', 1.3541323594780794), ('ventilator', 1.3522054059929411), ('adequate power', 1.3503235824218147), ('adequate', 1.3503235824218147), ('pakistan adequate', 1.3496947091717584), ('currently ventilator', 1.3492307063255586), ('ventilator hope', 1.3477470802713543), ('pray', 1.3476326659850464)]
# Topic 1:
# [('practically', 1.7388486611803822), ('bitcoin', 1.724474906582823), ('consumption', 0.8765588067125497), ('power consumption', 0.8759822440809593), ('consumption pakistan', 0.8751874528401342), ('equivalent', 0.8751324797115099), ('electricity equivalent', 0.8748918838937003), ('equivalent entire', 0.8748918838937003), ('entire power', 0.8748774719860616), ('consuming', 0.8742582191128493)]
# Topic 2:
# [('plunge', 1.9325169540897928), ('darkness', 1.8606628448404963), ('grid breakdown', 1.5321718253442373), ('national power', 1.5045974273332419), ('national', 1.4604440288827503), ('power grid', 1.3484246268401276), ('grid', 1.3086925764113477), ('breakdown', 1.292690886920724), ('plunge pakistan', 1.2609182713278824), ('pakistan darkness', 1.2597499933884837)]
# Topic 3:
# [('air force', 1.213160476167335), ('red alert', 1.1984789059707288), ('red', 1.1963528782275226), ('air', 1.1961905318707526), ('breakdown entire', 1.1960156562959345), ('force red', 1.1899192402624228), ('pakistan air', 1.1834960271147934), ('entire pakistan', 1.1812734452364453), ('alert', 1.1789897477343259), ('alert guy', 1.1679149184090802)]
# Topic 4:
# [('power blackout', 1.4302627432357828), ('multiple city', 1.3806113495341035), ('multiple', 1.3804808069550736), ('blackout reported', 1.3671429556086085), ('reported multiple', 1.3667337234176897), ('reported', 1.3629603774209245), ('pakistan medium', 1.3611244750087417), ('city pakistan', 1.360884203154528), ('city', 1.3212454945094825), ('medium', 1.2802188074847305)]
# Topic 5:
# [('population electricity', 1.2106280341062496), ('large population', 1.2106280341062496), ('leaf large', 1.2103362584774666), ('grid leaf', 1.2103362584774666), ('massive breakdown', 1.2102834292829492), ('leaf', 1.20860535973862), ('pakistan massive', 1.1898995847803469), ('breakdown country', 1.1835398452725785), ('population', 1.1690008467908444), ('large', 1.165563462809656)]
# ====================

# %%
# insert NMF model results back into dataframe
topic_values = nmf_model.transform(doc_term_matrix_1)
df['NMF_topic'] = topic_values.argmax(axis=1)
df.head(1)
# Out:
#                     id  \
# 0  1348110445333209091
#
#                                                     tweet_url  \
# 0  https://twitter.com/alienguru02/status/1348110445333209091
#
#                        created_at          parsed_created_at user_screen_name  \
# 0  Sun Jan 10 03:32:31 +0000 2021  2021-01-10 03:32:31+00:00  alienguru02
#
#                                                                      text  \
# 0  Power blackout reported in multiple cities of Pakistan: Pakistan media
#
#   tweet_type  coordinates hashtags media  ...  user_name  user_statuses_count  \
# 0  retweet   NaN           NaN      NaN   ...  I'm DeEp❤  16867
#
#   user_time_zone  user_urls  user_verified  \
# 0 NaN             NaN        False
#
#                                                              processed_text  \
# 0  [power, blackout, reported, multiple, cities, pakistan, pakistan, media]
#
#                                                                                                                      pos_tagged  \
# 0  [(power, NN), (blackout, NN), (reported, VBD), (multiple, JJ), (cities, NNS), (pakistan, VBP), (pakistan, JJ), (media, NNS)]
#
#                                                                 lemmatized  \
# 0  [power, blackout, reported, multiple, city, pakistan, pakistan, medium]
#
#                                                        final_docs  NMF_topic
# 0  power blackout reported multiple city pakistan pakistan medium  4
#
# [1 rows x 42 columns]

# %%
df.text[df.NMF_topic == 1][500:550]
# Out:
# 16452    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16453    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16454    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16456    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16457    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16458    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16459    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16460    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16461    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16462    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16463    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16464    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16465    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16470    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16471    @ZakaWaqar @ZakaWaqar bhai just have a look at his research 😂 Bitcoin mining is consuming electricity equivalent to the entire power consumption of Pakistan. I think this Mr is considering crypto mining as a super drilling machines 😂🔥 @AtifRMian lolllllsssss
# 16472    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16473    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16474    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16476    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16477    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16478    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16480    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16481    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16482    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16483    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16484    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16485    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16486    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16487    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16488    @ZakaWaqar 😂😂😂 consuming electricity equivalent to the entire power consumption of pakistan 😂😂😂
# 16490    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16491    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16492    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16493    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16494    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16496    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16497    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16499    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16500    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16501    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16503    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16504    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16505    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16506    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16507    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16508    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16510    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16511    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16512    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# 16513    Is Bitcoin worth it?\n\nBitcoin is socially wasteful and practically useless\n\nIt is consuming electricity equivalent to the entire power consumption of Pakistan, a country of 200M+\n\nAnd what use does it offer? Practically none. Its value only represents speculative craze. https://t.co/xLpGuGtNBy
# Name: text, dtype: object
