# %% [markdown]
# # Part 1: Data import and cleaning

# %%
#import initial libraries

import pandas as pd
import numpy as np

# %%
#import data after retweets removed using Twarc

df = pd.read_csv("data/osaka_NR.csv")

# %%
# look at basic info about data

df.info()
# 79111 Tweets total
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79111 entries, 0 to 79110
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            79111 non-null  int64
#  1   tweet_url                     79111 non-null  object
#  2   created_at                    79111 non-null  object
#  3   parsed_created_at             79111 non-null  object
#  4   user_screen_name              79111 non-null  object
#  5   text                          79111 non-null  object
#  6   tweet_type                    79111 non-null  object
#  7   coordinates                   1151 non-null   object
#  8   hashtags                      15414 non-null  object
#  9   media                         14895 non-null  object
#  10  urls                          31118 non-null  object
#  11  favorite_count                79111 non-null  int64
#  12  in_reply_to_screen_name       31738 non-null  object
#  13  in_reply_to_status_id         31265 non-null  float64
#  14  in_reply_to_user_id           31740 non-null  float64
#  15  lang                          79111 non-null  object
#  16  place                         2129 non-null   object
#  17  possibly_sensitive            39469 non-null  object
#  18  retweet_count                 79111 non-null  int64
#  19  retweet_or_quote_id           2494 non-null   float64
#  20  retweet_or_quote_screen_name  2494 non-null   object
#  21  retweet_or_quote_user_id      2494 non-null   float64
#  22  source                        79083 non-null  object
#  23  user_id                       79111 non-null  int64
#  24  user_created_at               79111 non-null  object
#  25  user_default_profile_image    79111 non-null  bool
#  26  user_description              76273 non-null  object
#  27  user_favourites_count         79111 non-null  int64
#  28  user_followers_count          79111 non-null  int64
#  29  user_friends_count            79111 non-null  int64
#  30  user_listed_count             79111 non-null  int64
#  31  user_location                 58128 non-null  object
#  32  user_name                     79111 non-null  object
#  33  user_statuses_count           79111 non-null  int64
#  34  user_time_zone                0 non-null      float64
#  35  user_urls                     43081 non-null  object
#  36  user_verified                 79111 non-null  bool
# dtypes: bool(2), float64(5), int64(9), object(21)
# memory usage: 21.3+ MB

# %%
# drop unnecessary columns 

df = df.drop(['tweet_url', 'created_at', 'media', 'urls','in_reply_to_screen_name',
       'in_reply_to_status_id', 'in_reply_to_user_id', 'retweet_or_quote_id',
       'retweet_or_quote_screen_name', 'retweet_or_quote_user_id', 'source',
       'user_created_at', 'user_name', 'user_verified', 'user_friends_count', 'user_listed_count',
       'user_statuses_count', 'user_default_profile_image', 'user_description',
       'user_favourites_count', 'user_followers_count', 'coordinates', 'user_location', 'user_time_zone', 'user_urls', 'place'], axis=1)

# %%
# check start time & date of data

df.iloc[0]

# first Tweet 2021-01-12 18:21:56
# Out:
# id                                                  1349059050374377473
# parsed_created_at                             2021-01-12 18:21:56+00:00
# user_screen_name                                        Shushanna_earle
# text                  @LouisVuitton Naomi Osaka 🇯🇵\n\nHi! 👁✌️♈️🐰👸 Ea...
# tweet_type                                                        reply
# hashtags                                                  Spring August
# favorite_count                                                        0
# lang                                                                 en
# possibly_sensitive                                                  NaN
# retweet_count                                                         0
# user_id                                                       381646187
# Name: 0, dtype: object

# %%
# check end time & date of data 

df.iloc[-1]

# last Tweet 2021-01-05 14:55:39+0
# Out:
# id                                                  1346470421227401221
# parsed_created_at                             2021-01-05 14:55:39+00:00
# user_screen_name                                             osakarefle
# text                  すぐ☆市内交通費無料☆最高の美魔女・美マダム♪／出張・派遣・出張マッサージ（出張・派遣エステ...
# tweet_type                                                     original
# hashtags                                                            NaN
# favorite_count                                                        0
# lang                                                                 ja
# possibly_sensitive                                                False
# retweet_count                                                         0
# user_id                                                       331824933
# Name: 79110, dtype: object

# %%
df.tail(20)
# Out:
#                         id          parsed_created_at user_screen_name  \
# 79091  1346471734086574085  2021-01-05 15:00:52+00:00  gakko_bot_osaka
# 79092  1346471719544840193  2021-01-05 15:00:48+00:00    Kichi_G_Osaka
# 79093  1346471683331244032  2021-01-05 15:00:40+00:00   baseball_osaka
# 79094  1346471671335567365  2021-01-05 15:00:37+00:00  tomobuilding109
# 79095  1346471665895522317  2021-01-05 15:00:36+00:00    _IBUKI_OSAKA_
# 79096  1346471602980982788  2021-01-05 15:00:21+00:00   First_Esthejob
# 79097  1346471601353572359  2021-01-05 15:00:20+00:00   goodroom_osaka
# 79098  1346471596710535171  2021-01-05 15:00:19+00:00     pworld_osaka
# 79099  1346471594827284485  2021-01-05 15:00:19+00:00     pworld_osaka
# 79100  1346471587080355840  2021-01-05 15:00:17+00:00     Mandarake_En
# 79101  1346471556919095310  2021-01-05 15:00:10+00:00   lovelife_osaka
# 79102  1346471531090612228  2021-01-05 15:00:03+00:00   thephilmiranda
# 79103  1346471453789589519  2021-01-05 14:59:45+00:00  KawagoeOpseqium
# 79104  1346471449985392651  2021-01-05 14:59:44+00:00  osaka_sirokichi
# 79105  1346471306691182596  2021-01-05 14:59:10+00:00    takoyaki_nice
# 79106  1346471042739421189  2021-01-05 14:58:07+00:00  Uber_NomoreLong
# 79107  1346470997050814472  2021-01-05 14:57:56+00:00       hogayabass
# 79108  1346470962959552514  2021-01-05 14:57:48+00:00       coomachiko
# 79109  1346470787281158145  2021-01-05 14:57:06+00:00      mofu_nyaaaa
# 79110  1346470421227401221  2021-01-05 14:55:39+00:00       osakarefle
#
#                                                     text tweet_type  \
# 79091                         【AクラスA帯】今日は4時限目からだね！　がんば！！   original
# 79092               @Kichi_G_Osaka 01-05のポスト数：5 (うちRT：1)   original
# 79093                        @japon1201 めっちゃわちゃわちゃしてるwww      reply
# 79094  @0building @osaka_sirokichi 梅田は本当にニューヨークです\nオフ...      reply
# 79095  @perochiro5516 と言いながらいつも手に入れてるでしょ⁉️ってか。。。手に握って...      reply
# 79096  「ソフトなお仕事がいい」\n「お給料は妥協したくない」\nそんな方に『firstclass』...   original
# 79097  ただいまが待ち遠しい\n西院 1K 23.78㎡\n #ひとり暮らし7万円以下\nhttps...   original
# 79098  Ａ　ＴＩＭＥ梅田御堂筋店　2021/01/06(水）１０時OPEN ブログ更新！ 皆様のご来...   original
# 79099  プレミアSLOT　LAB淡路西店　6日(水)新台入替2日目！本日10時開店！！ 最新台・人気...   original
# 79100  ★Mandarake Latest Store Topics★\nJanuary 5 21p...   original
# 79101  🌟日払い！　シフト自由！　接客不要のアルバイト🌟\n\nラブライフではアルバイト募集中です！...   original
# 79102  Aflac Parents House, established in 2001 throu...   original
# 79103                 @kimitoki_osaka コクリアまた名前変わったんですか？？      reply
# 79104                         新海誠に大阪舞台の作品を一本、作ってもらいたいねぇ！   original
# 79105  @jiro2109 「同学校で陽性が判明している教職員5名の濃厚接触者ではありません。またそ...      reply
# 79106  @osaka_uber 自己矛盾しまくりでどこからツッコんでいいのか分かりませんが🤣、とりあ...      reply
# 79107              @dardevsco Osaka to be specific 🤦🏻‍♂️      reply
# 79108  大フィルもクラウドファンディング😢\n応援してください。\n\n大阪フィル・クラウドファンデ...   original
# 79109                                 @yattande_osaka あが      reply
# 79110  すぐ☆市内交通費無料☆最高の美魔女・美マダム♪／出張・派遣・出張マッサージ（出張・派遣エステ...   original
#
#                                 hashtags  favorite_count lang  \
# 79091                                NaN               0   ja
# 79092                                NaN               0   ja
# 79093                                NaN               0   ja
# 79094                                NaN               3   ja
# 79095                                NaN               0   ja
# 79096                                NaN               0   ja
# 79097                        ひとり暮らし7万円以下               0   ja
# 79098                                NaN               0   ja
# 79099                                NaN               0   ja
# 79100                          Mandarake               0   en
# 79101  求人 アルバイト 高収入 日払い 体験入店 接客不要 ビラ配り無し               0   ja
# 79102                                NaN               0   en
# 79103                                NaN               0   ja
# 79104                                NaN               3   ja
# 79105                                NaN               9   ja
# 79106                                NaN               0   ja
# 79107                                NaN               0   sl
# 79108                        クラウドファンディング               0   ja
# 79109                                NaN               2   ja
# 79110                                NaN               0   ja
#
#       possibly_sensitive  retweet_count              user_id
# 79091                NaN              0            472728036
# 79092                NaN              0           3504748992
# 79093                NaN              0           1310383622
# 79094                NaN              0   989890048865718272
# 79095                NaN              0  1337971173334765569
# 79096               True              0  1281907293152440321
# 79097              False              0           2253106794
# 79098              False              0            143724180
# 79099              False              0            143724180
# 79100              False              0           3311205248
# 79101              False              0           2888232438
# 79102              False              0   785559468759060485
# 79103                NaN              0           1713158270
# 79104                NaN              0            226090046
# 79105              False             11           3896793613
# 79106                NaN              0  1335926034814754817
# 79107                NaN              0  1292469064879583232
# 79108              False              2            129062000
# 79109                NaN              0  1337430496012165122
# 79110              False              0            331824933

# %%
# count number of languages in data set

count_lang = df['lang'].unique()
print(len(count_lang), count_lang)
# Out:
# 43 ['en' 'ja' 'pt' 'fr' 'ko' 'et' 'in' 'es' 'ar' 'tr' 'und' 'pl' 'fi' 'ca'
#  'el' 'hu' 'it' 'de' 'th' 'tl' 'eu' 'hi' 'nl' 'ht' 'cs' 'zh' 'no' 'sv'
#  'vi' 'uk' 'lv' 'sl' 'ru' 'bg' 'ro' 'da' 'is' 'lt' 'kn' 'fa' 'ur' 'sr'
#  'cy']

# %%
# tweets are in 43 different languages

# I'll be working only with Tweets in English
# drop tweets in all other languages
# now working with 38884 Tweets 

df = df[df.lang == 'en']
df.shape
# Out:
# (5877, 11)

# %%
# without non-English Tweets, data set reduced to just 5877

# %% [markdown]
# # Part 2: Text processing for NLP

# %%
# create variable for "text" column 
text = df['text']

# %%
# tokenize, remove stopwords, remove urls, lowercase, remove punctuation, remove numbers

# import necessary libraries: ntlk etc.

import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 


stop = stopwords.words('english')

punc = list(set(string.punctuation))

def tokenizer(text):
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(text)
    return tokens

def remove_url(text):
    url = re.compile(r"https?://\S+|www\.\S+")
    return url.sub(r'', text)

def process_text(text):
    text = remove_url(text)
    text = tokenizer(text)
    text = [word.lower() for word in text]
    text = [re.sub('[0-9]+', '', word) for word in text]
    text = [word for word in text if word not in punc]
    text = [word for word in text if word not in stop]
    text = [each for each in text if len(each) > 1]
    text = [word for word in text if ' ' not in word]
     
    return text

# %%
# apply text processing functions to text

df['processed_text'] = df['text'].apply(process_text)

# %%
# look at some of processed text

pd.set_option('display.max_colwidth', -1)
df['processed_text'][:20]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0      [@louisvuitton, naomi, osaka, hi, easter, april, nd, #spring, ️⃣, ️️⃣️⃣, ️⃣️⃣, #august, th, summer, uk]
# 16     [building, beautiful, comforting, whimsical, frightening, otherwise, awe-inspiring, something's, gone, horribly, wrong, images, waste, disposal, facility, osaka, last, excuse, miserable, drab, architecture, died, erected]
# 18     [@pckltheproto, ah, see, asphalt, pain, mobile, sometimes, especially, osaka]
# 19     [mandarake, latest, store, topics, january, pm, update, grand, chaos, osaka, male, idol, arrival, information, group, face, towels, stock, #mandarake]
# 21     [@yunchimu_cos, @kazuno_co, @airoute_osaka, hooot]
# 33     [wanna, go, osaka, today, field]
# 35     [naomi, osaka, revealed, new, face, louis, vuitton, via, @cnnstyle, #brands]
# 69     [osaka, might, known, buzzing, metropolis, skyscrapers, neon, lights, ...]
# 70     [osaka, might, known, buzzing, metropolis, skyscrapers, neon, lights, ...]
# 80     [people, question, naomi, osaka, success, actually, baffling, lmfaoooooooo, girl, literally, bagged, slams, years, row]
# 85     [ray, light, otherwise, bleak, news, cycle, ..., naomi, osaka, revealed, new, face, louis, vuitton]
# 87     [shannon, osaka, city, truly, renewable, complicated, @grist]
# 95     [wind, moving, osaka, meter, sec, degrees]
# 110    [show, naomi, osaka, abby, dahlkemper, jessie, diggins, episode, warm]
# 113    [@faceitrainbow, @teambds, @cloud, @darkzerogg, @fazeclan, @gesports, @giantsgaming, @mibr, @nipgaming, @oxg_esports, @spacestationgg, @team_empire, @teamliquid, @teamoneesports, @tsm, @virtuspro, @wildcard_gg, @cyclops_osaka, @mkersofficial, @altioragg, @furia, space, station]
# 116    [osaka, japan, born]
# 117    [@kjhthinker, preach]
# 118    [want, osaka, rn]
# 119    [grow, want, soccer, naomi, osaka]
# 127    [naomi, osaka, revealed, new, face, louis, vuitton, reported, new, louis, vuitton, ambassador, naomi, osaka, fashion, wanted, #sportsnews, #myboysay]
# Name: processed_text, dtype: object

# %%
# part-of-speech tagging 

ready_for_pos = df['processed_text']

def pos_tagging(text):
    pos_tag = [pos_tag(word) for word in ready_for_pos]

df['pos_tagged'] = df.processed_text.apply(lambda x: pos_tag(x))

# %%
# lemmatizing

pos_tagged = df['pos_tagged']

wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
pos_tagged = df['pos_tagged']

# %%
# lemmatizing

from nltk.stem import WordNetLemmatizer 
wordnet = WordNetLemmatizer() 

lemmatized = [[wordnet.lemmatize(word[0]) for word in words] for words in pos_tagged]

# %%
# look at lemmatized text

df['lemmatized'] = lemmatized
lemmatized[:20]
# Out:
# [['@louisvuitton',
#   'naomi',
#   'osaka',
#   'hi',
#   'easter',
#   'april',
#   'nd',
#   '#spring',
#   '️⃣',
#   '️️⃣️⃣',
#   '️⃣️⃣',
#   '#august',
#   'th',
#   'summer',
#   'uk'],
#  ['building',
#   'beautiful',
#   'comforting',
#   'whimsical',
#   'frightening',
#   'otherwise',
#   'awe-inspiring',
#   "something's",
#   'gone',
#   'horribly',
#   'wrong',
#   'image',
#   'waste',
#   'disposal',
#   'facility',
#   'osaka',
#   'last',
#   'excuse',
#   'miserable',
#   'drab',
#   'architecture',
#   'died',
#   'erected'],
#  ['@pckltheproto',
#   'ah',
#   'see',
#   'asphalt',
#   'pain',
#   'mobile',
#   'sometimes',
#   'especially',
#   'osaka'],
#  ['mandarake',
#   'latest',
#   'store',
#   'topic',
#   'january',
#   'pm',
#   'update',
#   'grand',
#   'chaos',
#   'osaka',
#   'male',
#   'idol',
#   'arrival',
#   'information',
#   'group',
#   'face',
#   'towel',
#   'stock',
#   '#mandarake'],
#  ['@yunchimu_cos', '@kazuno_co', '@airoute_osaka', 'hooot'],
#  ['wanna', 'go', 'osaka', 'today', 'field'],
#  ['naomi',
#   'osaka',
#   'revealed',
#   'new',
#   'face',
#   'louis',
#   'vuitton',
#   'via',
#   '@cnnstyle',
#   '#brands'],
#  ['osaka',
#   'might',
#   'known',
#   'buzzing',
#   'metropolis',
#   'skyscraper',
#   'neon',
#   'light',
#   '...'],
#  ['osaka',
#   'might',
#   'known',
#   'buzzing',
#   'metropolis',
#   'skyscraper',
#   'neon',
#   'light',
#   '...'],
#  ['people',
#   'question',
#   'naomi',
#   'osaka',
#   'success',
#   'actually',
#   'baffling',
#   'lmfaoooooooo',
#   'girl',
#   'literally',
#   'bagged',
#   'slam',
#   'year',
#   'row'],
#  ['ray',
#   'light',
#   'otherwise',
#   'bleak',
#   'news',
#   'cycle',
#   '...',
#   'naomi',
#   'osaka',
#   'revealed',
#   'new',
#   'face',
#   'louis',
#   'vuitton'],
#  ['shannon', 'osaka', 'city', 'truly', 'renewable', 'complicated', '@grist'],
#  ['wind', 'moving', 'osaka', 'meter', 'sec', 'degree'],
#  ['show',
#   'naomi',
#   'osaka',
#   'abby',
#   'dahlkemper',
#   'jessie',
#   'diggins',
#   'episode',
#   'warm'],
#  ['@faceitrainbow',
#   '@teambds',
#   '@cloud',
#   '@darkzerogg',
#   '@fazeclan',
#   '@gesports',
#   '@giantsgaming',
#   '@mibr',
#   '@nipgaming',
#   '@oxg_esports',
#   '@spacestationgg',
#   '@team_empire',
#   '@teamliquid',
#   '@teamoneesports',
#   '@tsm',
#   '@virtuspro',
#   '@wildcard_gg',
#   '@cyclops_osaka',
#   '@mkersofficial',
#   '@altioragg',
#   '@furia',
#   'space',
#   'station'],
#  ['osaka', 'japan', 'born'],
#  ['@kjhthinker', 'preach'],
#  ['want', 'osaka', 'rn'],
#  ['grow', 'want', 'soccer', 'naomi', 'osaka'],
#  ['naomi',
#   'osaka',
#   'revealed',
#   'new',
#   'face',
#   'louis',
#   'vuitton',
#   'reported',
#   'new',
#   'louis',
#   'vuitton',
#   'ambassador',
#   'naomi',
#   'osaka',
#   'fashion',
#   'wanted',
#   '#sportsnews',
#   '#myboysay']]

# %%
# before vectorizing, cast lists of words back into strings

df['final_docs'] = df['lemmatized'].apply(lambda x: " ".join(x))
pd.set_option('display.max_colwidth', -1)
final_docs = df['final_docs']
final_docs[3000:3020]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# 40730    travis japan live tour image nation decided postpone performance target performance would postpone kyoto kanagawa osaka
# 40751    come osaka support trip
# 40793    名古屋発 wireless internet connection service available train shin-osaka tokyo
# 40800    next osaka
# 40824    @tyribs kagura sheesh remember watching movie back okinawa still favorite disney movie time osaka ah understand people hate brother bear
# 40831    nod finger barely ghosting tsum's glistening tip can't wait eat next time yer osaka add tsum natsu moan biting lip sho move one thumb brush top clit also know like clit teased sho say
# 40847    @tanyainrl chicago boy prince osaka
# 40878    nonexistent chance spotting one jackalopes tomorrow use caution around osaka area
# 40960    stop osaka ryouta cute cant
# 40968    grow saving get usa resident #hongkong #indonesia #argentina #saopaolo #venezuela #netherlands #africa #osaka #vietnam #taiwan #singapore #germany #belgium #india #spain #italy #austria #nigeria #hongkongers #colombia
# 40988    song jungkook osaka gcf repeat day good
# 41001    high chance spotting bigfoot's second cousin dennis next hour use caution around osaka area
# 41006    ...sat store muze collection circle knit beret mw kn size free color black turquoise tax #muze_tokyo #muzetokyo
# 41043    watch happened @kanji_k broadcast classic car museum near port #osaka #japan @periscopeco
# 41044    @osaka_ @dannyodwyer can't lie sound look good
# 41045    @osaka_hoe help
# 41054    @kitty_ramune already need i'm flat bra
# 41066    website super nintendo world universal studio japan let virtually explore park delicious food via @grapejapan #supernintendoworld #osaka
# 41086    @tyribs osaka oh remember guy make puppet show yomi bet ending one person playing funeral
# 41124    @heyitspyxis @dannyodwyer course cow like sound milkshake beer
# Name: final_docs, dtype: object

# %% [markdown]
# # Run NMF and LDA topic modeling...

# %%
#create document term matrix with TFIDF

#import vectorizing tool (usee TFIDF)
from sklearn.feature_extraction.text import TfidfVectorizer
# set max_features to 2000 (specifies the number of most frequently occurring words for which we want to create feature vectors)
# set min_df to 5 (word must occur in at least 5 documents)
# set max_df to 0.85 (word must not occur in more than 85 percent of the documents) 

tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.85, ngram_range=(1, 2), stop_words='english')  
doc_term_matrix_1 = tfidfconverter.fit_transform(df['final_docs'].values.astype('U'))

# %%
#run NMF model 

#import NMF tool 
from sklearn.decomposition import NMF

nmf_model = NMF(n_components=6)
nmf_Z = nmf_model.fit_transform(doc_term_matrix_1)

# %%
# run LDA model

#import LDA tool 
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 6, max_iter=10, learning_method='online', learning_decay=.9)
lda_Z = lda_model.fit_transform(doc_term_matrix_1)

# %%
def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model:")
print_topics(lda_model, tfidfconverter )
print("=" * 30)
 
print("NMF Model:")
print_topics(nmf_model, tfidfconverter )
print("=" * 30)
# Out:
# LDA Model:
# Topic 0:
# [('osaka', 72.53348250537218), ('good', 67.17969644020118), ('like', 35.05454988168213), ('tokyo', 34.37924221598088), ('time', 30.332000537049556), ('japan', 29.674322584643832), ('miss', 27.422886249663893), ('feel', 26.667513322226952), ('know', 23.23650908493094), ('morning', 21.360461500193093)]
# Topic 1:
# [('osaka', 104.04241869575141), ('naomi', 86.67572601065731), ('naomi osaka', 83.0297576275838), ('osaka_hoe', 69.21374281117721), ('louis', 29.72955767545962), ('love', 29.637708762322976), ('vuitton', 29.111726526863173), ('tennis', 28.691641258167746), ('louis vuitton', 28.349829107910715), ('naomiosaka', 26.065884844083904)]
# Topic 2:
# [('osaka', 92.14963971229551), ('like', 35.94596954607748), ('osaka_hoe', 29.018168395306787), ('tyribs', 28.69826312187444), ('got', 26.84727049254369), ('think', 24.068349923570846), ('snow', 23.20108069719816), ('japan', 23.005983284666073), ('come', 22.869794415514814), ('osaka_a_', 22.84477989857915)]
# Topic 3:
# [('mandarake', 53.39348155928715), ('osaka', 51.24701999316988), ('store', 36.202696297367794), ('january', 35.57627034696597), ('live', 32.36464581778742), ('pm', 30.787837428681023), ('update', 30.711616955516543), ('japan', 30.53055946913108), ('th', 29.849227604242092), ('osaka_a_', 29.34360437569053)]
# Topic 4:
# [('osaka', 67.87386258532618), ('japan', 57.78772299913363), ('emergency', 57.50074502969991), ('kyoto', 52.8769276494928), ('state', 49.66523511633513), ('state emergency', 45.84179972423213), ('tokyo', 41.645578932498545), ('covid', 35.1259115434869), ('area', 33.02604668698776), ('prefecture', 32.40577588141185)]
# Topic 5:
# [('osaka', 29.30662089261848), ('degree', 28.830192421095802), ('moving', 28.73153599310354), ('wind', 27.900266094083644), ('moving osaka', 27.521722113438212), ('meter', 27.155775340266114), ('sec', 26.288463224946312), ('sec degree', 26.288276285499155), ('osaka meter', 26.28803090905998), ('wind moving', 26.287892661550295)]
# ==============================
# NMF Model:
# Topic 0:
# [('osaka', 3.2948149579636468), ('japan', 0.6344217687386099), ('osaka japan', 0.5001309425068413), ('like', 0.3913450672334871), ('good', 0.30711691770991206), ('tokyo', 0.30414235931748274), ('live', 0.26225166521208565), ('love', 0.24902983095324477), ('time', 0.24522026376741857), ('year', 0.23771310994673514)]
# Topic 1:
# [('mandarake', 1.2162271470794475), ('store', 0.6590159354230228), ('january pm', 0.6126618247852174), ('latest', 0.6099947329981386), ('chaos', 0.6086778741127549), ('store topic', 0.6081135735397237), ('grand chaos', 0.6081135735397237), ('update grand', 0.6081135735397237), ('pm update', 0.6081135735397237), ('topic january', 0.6081135735397237)]
# Topic 2:
# [('degree', 0.9434520736557332), ('moving osaka', 0.9404464472196958), ('sec', 0.9390318497185056), ('sec degree', 0.9390318497185056), ('wind moving', 0.9390318497185056), ('meter sec', 0.9390318497185056), ('osaka meter', 0.9390318497185056), ('moving', 0.9331351073285981), ('meter', 0.9288567995863917), ('wind', 0.9284925322961194)]
# Topic 3:
# [('osaka_hoe', 2.8881354641521857), ('thank', 0.22247707679095352), ('osaka_hoe thank', 0.16669893972361852), ('like', 0.1269635687858504), ('yes', 0.117877439098898), ('ur', 0.10233241228638398), ('omg', 0.08274210993505617), ('cute', 0.07952065961077291), ('need', 0.07859426340744052), ('yeah', 0.07765806143094471)]
# Topic 4:
# [('naomi', 1.5390285422718757), ('naomi osaka', 1.496017541910041), ('louis', 0.7553866060839467), ('vuitton', 0.739264571482347), ('louis vuitton', 0.7280817143766009), ('new', 0.4884592266827418), ('face', 0.42960381021890565), ('face louis', 0.4132937448366565), ('new face', 0.4005022849776247), ('ambassador', 0.399663727050811)]
# Topic 5:
# [('emergency', 1.1284927064095125), ('state', 0.9994984788283084), ('state emergency', 0.9906963815862253), ('kyoto', 0.9035396972563093), ('japan', 0.8366125620148359), ('hyogo', 0.7105846639734268), ('osaka kyoto', 0.5683092984801653), ('covid', 0.5204256693003662), ('prefecture', 0.47780289684127814), ('kyoto hyogo', 0.4093122780970896)]
# ==============================

# %% [markdown]
# # Part 4: Run visualization and testing of LDA model

# %%
# visualization of LDA model 
import pyLDAvis.sklearn

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model, doc_term_matrix_1, tfidfconverter, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=               x          y  topics  cluster       Freq
# topic
# 4      1.465019  -47.625065  1       1        19.578598
# 2      54.854797 -36.476795  2       1        18.225473
# 0      32.212929 -61.444572  3       1        17.598256
# 3      5.111096  -14.110332  4       1        17.274574
# 1      26.350170 -33.374702  5       1        14.555004
# 5      38.109818 -7.222781   6       1        12.768095, topic_info=             Term       Freq       Total Category  logprob  loglift
# 1110  naomi        80.000000  80.000000   Default  30.0000  30.0000
# 1111  naomi osaka  76.000000  76.000000   Default  29.0000  29.0000
# 1261  osaka_hoe    88.000000  88.000000   Default  28.0000  28.0000
# 643   good         64.000000  64.000000   Default  27.0000  27.0000
# 986   mandarake    48.000000  48.000000   Default  26.0000  26.0000
# ...         ...          ...        ...       ...      ...      ...
# 936   ll           13.768137  24.235957   Topic6  -4.9783   1.4927
# 1622  start        11.272863  16.949758   Topic6  -5.1783   1.6504
# 1858  video        11.312184  22.481286   Topic6  -5.1748   1.3714
# 1184  osaka        27.437957  370.349463  Topic6  -4.2887  -0.5443
# 711   hello        9.453125   19.818650   Topic6  -5.3543   1.3179
#
# [301 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 0     3      0.942295  able
# 1     2      0.901555  absolutely
# 4     6      0.860622  accent
# 11    2      0.917677  actually
# 11    3      0.070591  actually
# ...  ..           ...       ...
# 1973  3      0.548530  yes
# 1973  5      0.096799  yes
# 1980  2      0.938251  yomi
# 1985  6      0.965658  youtube
# 1991  4      0.971166  zedd
#
# [443 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 3, 1, 4, 2, 6])

# %%
# test LDA model

# log likelihood (higher score is better)
print("Log likelihood: ", lda_model.score(doc_term_matrix_1))


# perplexity (lower score is better)
print("Perplexity: ", lda_model.perplexity(doc_term_matrix_1))
# Out:
# Log likelihood:  -121662.82469195458
# Perplexity:  2366.061070091787

# %%
# cross-validation to find best parameters for LDA model

#import cross-validation tool
from sklearn.model_selection import GridSearchCV

# define search parameters
search_params = {'n_components': [5, 8, 10, 12], 'learning_decay': [.5, .7, .9]}

# initialize model for cross-validation
lda = LatentDirichletAllocation()

# initialize grid search class 
model = GridSearchCV(lda, param_grid=search_params)

# run grid search 
model.fit(doc_term_matrix_1)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 8, 10, 12]})

# %%
# what is best model? 
best_lda_model = model.best_estimator_

# print parameters for best model
print("Parameters for best model: ", model.best_params_)

# print log likelihood score
print("Log likelihood score of best model: ", model.best_score_)

# print perplexity score
print("Perplexity score of best model: ", best_lda_model.perplexity(doc_term_matrix_1))
# Out:
# Parameters for best model:  {'learning_decay': 0.9, 'n_components': 5}
# Log likelihood score of best model:  -30332.20533584759
# Perplexity score of best model:  2349.6595325443373

# %%
# 2nd LDA model: running new "best model" parameters

lda_model_2 = LatentDirichletAllocation(n_components = 5, max_iter=10, learning_method='online', learning_decay=0.9)
lda_Z_2 = lda_model_2.fit_transform(doc_term_matrix_1)

# visualization of 2nd LDA model 
pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model_2, doc_term_matrix_1, tfidfconverter, mds='tsne')
panel

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model_2, doc_term_matrix_1, tfidfconverter, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 2      150.222153 -72.269554   1       1        26.643477
# 4      51.163364  -159.968018  2       1        20.742214
# 3     -73.144554   21.523815   3       1        18.606522
# 1     -66.410133  -110.606438  4       1        18.152363
# 0      54.417324   12.443444   5       1        15.855424, topic_info=             Term       Freq       Total Category  logprob  loglift
# 1110  naomi        81.000000  81.000000   Default  30.0000  30.0000
# 1111  naomi osaka  78.000000  78.000000   Default  29.0000  29.0000
# 986   mandarake    51.000000  51.000000   Default  28.0000  28.0000
# 921   like         75.000000  75.000000   Default  27.0000  27.0000
# 1260  osaka_a_     50.000000  50.000000   Default  26.0000  26.0000
# ...        ...           ...        ...       ...      ...      ...
# 931   live         18.629942  47.812151   Topic5  -4.8924   0.8991
# 1184  osaka        40.119188  366.182610  Topic5  -4.1254  -0.3696
# 1715  tennis       13.041066  27.673617   Topic5  -5.2491   1.0893
# 936   ll           11.926367  23.528704   Topic5  -5.3385   1.1622
# 1261  osaka_hoe    15.178859  86.562415   Topic5  -5.0973   0.1007
#
# [273 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 1     2      0.880546  absolutely
# 11    2      0.965473  actually
# 68    1      0.971720  area
# 72    4      0.953906  arrival
# 84    1      0.899259  ask
# ...  ..           ...      ...
# 1985  1      0.155174  youtube
# 1985  2      0.724144  youtube
# 1985  3      0.103449  youtube
# 1989  2      0.925903  yuta
# 1991  2      0.934724  zedd
#
# [373 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 5, 4, 2, 1])

# %%
# top topics of 2nd LDA model

def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])
 
print("LDA Model 2:")
print_topics(lda_model_2, tfidfconverter )
print("=" * 20)
# Out:
# LDA Model 2:
# Topic 0:
# [('naomi', 60.221399351266925), ('naomi osaka', 58.256653209180946), ('osaka_a_', 45.09035575558274), ('osaka', 43.03167253376221), ('love', 33.27705326391462), ('new', 27.561186933407626), ('louis', 22.35543193918133), ('cyclops_osaka', 22.33109758752179), ('vuitton', 21.686891560324412), ('louis vuitton', 20.855817466484485)]
# Topic 1:
# [('mandarake', 53.42106711806818), ('osaka', 41.966857777189794), ('store', 36.17558327236706), ('january', 32.44217154406846), ('update', 30.89491095390192), ('grand', 30.57518288713845), ('pm', 30.31914172994808), ('latest', 29.146710464550765), ('degree', 28.86748380189281), ('moving', 28.765148828472206)]
# Topic 2:
# [('osaka', 170.08979468586773), ('japan', 85.02809830778891), ('tokyo', 61.822897293743566), ('emergency', 57.53388085315272), ('kyoto', 52.856383473780085), ('state', 49.7162789531687), ('osaka_hoe', 48.3218801847458), ('state emergency', 45.87480226815649), ('time', 39.691476082804286), ('covid', 34.825661068936604)]
# Topic 3:
# [('osaka', 69.45874484848272), ('thank', 44.74637070426367), ('good', 35.52293104151861), ('morning', 22.866769694033955), ('today', 22.092874049545326), ('check', 21.82852056784916), ('nowplaying', 21.617329932058013), ('life', 21.05700819524894), ('nct', 20.262285766545787), ('japan', 18.980794629074516)]
# Topic 4:
# [('osaka', 92.60292709436415), ('like', 67.39597816816442), ('japan', 33.03964325958265), ('want', 31.845782065423734), ('tyribs', 28.611121481117255), ('got', 27.400121597414707), ('osaka_hoe', 26.604981930931128), ('yes', 25.72124296931006), ('snow', 23.310749867647278), ('make', 23.18245595959679)]
# ====================

# %%
# make results of LDA2 model a column in dataframe

topic_values = lda_model_2.transform(doc_term_matrix_1)
df['LDA2_topic'] = topic_values.argmax(axis=1)
